# %% [markdown]
# ### Code to connect, acquire and store raw data from red pitaya from both CH1 and CH2 simulatenusly
#
# ### using config.json for manual device labelling
#
# ### data stored in data/[device]/[date]/session_000_CH#.csv
#
# ### author: Augusto

# %% [markdown]
# # 1. legacy data collection using SCPI server (sends buffers periodically)

# %%
import numpy as np
import pandas as pd
import redpitaya_scpi as scpi
import time
import datetime
import os
import json
import re
import sys

# Function to load configurations from config.json
def load_config(config_path='config.json'):
    if not os.path.exists(config_path):
        raise FileNotFoundError(f"Configuration file '{config_path}' not found.")
    
    with open(config_path, 'r') as config_file:
        config = json.load(config_file)
    
    # Validate required keys
    required_keys = ["ip_address", "device_label", "decimation_factor", "base_dir", "session_delay_seconds"]
    for key in required_keys:
        if key not in config:
            raise KeyError(f"Missing required configuration key: '{key}'")
    
    return config

# Function to determine the next session index based on existing files
def get_next_session_index(date_dir):
    # Pattern to match session files e.g., session_023.csv
    pattern = re.compile(r'session_(\d{3})\.csv')
    existing_sessions = []
    
    if not os.path.exists(date_dir):
        return 1  # No existing sessions
    
    for filename in os.listdir(date_dir):
        match = pattern.match(filename)
        if match:
            session_num = int(match.group(1))
            existing_sessions.append(session_num)
    
    if not existing_sessions:
        return 1  # No existing sessions
    else:
        return max(existing_sessions) + 1  # Next session index

# Function to initialize CSV files with headers
def initialize_csv(filepath):
    with open(filepath, 'w') as f:
        f.write('voltage_ch1,voltage_ch2,timestamp\n')  # Header

# Function to append data to a single merged CSV
def append_to_csv(filepath, timestamp, voltage_ch1, voltage_ch2):
    # Create a list of timestamps: first element is timestamp, rest are empty strings
    timestamps = [timestamp] + [''] * (len(voltage_ch1) - 1)
    df = pd.DataFrame({
        'voltage_ch1': voltage_ch1,
        'voltage_ch2': voltage_ch2,
        'timestamp': timestamps,
    })
    df.to_csv(filepath, mode='a', header=False, index=False)

# Main data collection function
def collect_data(config):
    # Extract configurations
    IP = config['ip_address']
    device_label = config['device_label']
    decimation_factor = config['decimation_factor']
    base_dir = config['base_dir']
    session_delay = config['session_delay_seconds']
    
    # Initialize Red Pitaya connection
    try:
        rp_s = scpi.scpi(IP)
        print(f"Connected to Red Pitaya at {IP}")
    except Exception as e:
        print(f"Failed to connect to Red Pitaya at {IP}: {e}")
        sys.exit(1)
    
    # Create device directory if it doesn't exist
    device_dir = os.path.join(base_dir, device_label)
    os.makedirs(device_dir, exist_ok=True)
    
    # Get current date for organizing files
    current_date = datetime.datetime.now().strftime('%Y-%m-%d')
    date_dir = os.path.join(device_dir, current_date)
    os.makedirs(date_dir, exist_ok=True)
    
    # Determine the next session index
    session_index = get_next_session_index(date_dir)
    print(f"Starting at session index: {session_index}")
    
    try:
        while True:
            print(f"Starting data collection for session {session_index} with label '{device_label}'")
    
            # Get current timestamp for session start
            session_start_time = datetime.datetime.now().isoformat()

            # Configure Red Pitaya once before acquiring data
            try:
                rp_s.tx_txt('ACQ:RST')  # Reset acquisition
                rp_s.tx_txt(f'ACQ:DEC {decimation_factor}')  # Set decimation factor
                rp_s.tx_txt('ACQ:TRIG:LEV -1')  # Set trigger level
                rp_s.tx_txt('ACQ:START')  # Start acquisition
                print("Red Pitaya configured successfully.")
            except Exception as e:
                print(f"Error configuring Red Pitaya: {e}")
                sys.exit(1)
    
            # Trigger on both channels
            try:
                rp_s.tx_txt('ACQ:TRIG CH1_PE')
                rp_s.tx_txt('ACQ:TRIG CH2_PE')
                time.sleep(1)  # Wait for trigger and acquisition
            except Exception as e:
                print(f"Error triggering acquisition: {e}")
                time.sleep(session_delay)
                continue  # Skip to next iteration
    
            # Capture data from both channels
            try:
                rp_s.tx_txt('ACQ:SOUR1:DATA?')
                raw_data_ch1 = rp_s.rx_txt().strip('{}\n\r').split(',')
                signal_ch1 = np.array([float(x) for x in raw_data_ch1])
                signal_ch1 -= np.mean(signal_ch1)  # Remove DC component

                rp_s.tx_txt('ACQ:SOUR2:DATA?')
                raw_data_ch2 = rp_s.rx_txt().strip('{}\n\r').split(',')
                signal_ch2 = np.array([float(x) for x in raw_data_ch2])
                signal_ch2 -= np.mean(signal_ch2)  # Remove DC component

                if signal_ch1.size > 0 and signal_ch2.size > 0:
                    # Initialize file path for the current session
                    session_filepath = os.path.join(date_dir, f'session_{session_index:03d}.csv')
                    initialize_csv(session_filepath)

                    # Append data to the single CSV file
                    append_to_csv(session_filepath, session_start_time, signal_ch1, signal_ch2)
                    print(f"Session {session_index} data saved.")
                    session_index += 1  # Increment only after successful data saving
                else:
                    print(f"No data captured for session {session_index}.")
            except Exception as e:
                print(f"Error acquiring data: {e}")
    
            # Optional: Control data collection rate
            time.sleep(session_delay)  # Delay before the next session
    except KeyboardInterrupt:
        print("\nData collection stopped by user.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    finally:
        print(f"Data collection terminated. Last session index: {session_index - 1}")

# Entry point of the script
if __name__ == "__main__":
    try:
        config = load_config('config.json')
    except (FileNotFoundError, KeyError) as e:
        print(f"Configuration Error: {e}")
        sys.exit(1)
    
    collect_data(config)
# Out:
# Connected to Red Pitaya at 192.168.8.214
# Starting at session index: 11
# Starting data collection for session 11 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 11 data saved.
# Starting data collection for session 12 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 12 data saved.
# Starting data collection for session 13 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 13 data saved.
# Starting data collection for session 14 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 14 data saved.
# Starting data collection for session 15 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 15 data saved.
# Starting data collection for session 16 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 16 data saved.
# Starting data collection for session 17 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 17 data saved.
# Starting data collection for session 18 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 18 data saved.
# Starting data collection for session 19 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 19 data saved.
# Starting data collection for session 20 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 20 data saved.
# Starting data collection for session 21 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 21 data saved.
# Starting data collection for session 22 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 22 data saved.
# Starting data collection for session 23 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 23 data saved.
# Starting data collection for session 24 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 24 data saved.
# Starting data collection for session 25 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 25 data saved.
# Starting data collection for session 26 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 26 data saved.
# Starting data collection for session 27 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 27 data saved.
# Starting data collection for session 28 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 28 data saved.
# Starting data collection for session 29 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 29 data saved.
# Starting data collection for session 30 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 30 data saved.
# Starting data collection for session 31 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 31 data saved.
# Starting data collection for session 32 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 32 data saved.
# Starting data collection for session 33 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 33 data saved.
# Starting data collection for session 34 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 34 data saved.
# Starting data collection for session 35 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 35 data saved.
# Starting data collection for session 36 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 36 data saved.
# Starting data collection for session 37 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 37 data saved.
# Starting data collection for session 38 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 38 data saved.
# Starting data collection for session 39 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 39 data saved.
# Starting data collection for session 40 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 40 data saved.
# Starting data collection for session 41 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 41 data saved.
# Starting data collection for session 42 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 42 data saved.
# Starting data collection for session 43 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 43 data saved.
# Starting data collection for session 44 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 44 data saved.
# Starting data collection for session 45 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 45 data saved.
# Starting data collection for session 46 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 46 data saved.
# Starting data collection for session 47 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 47 data saved.
# Starting data collection for session 48 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 48 data saved.
# Starting data collection for session 49 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 49 data saved.
# Starting data collection for session 50 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 50 data saved.
# Starting data collection for session 51 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 51 data saved.
# Starting data collection for session 52 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 52 data saved.
# Starting data collection for session 53 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 53 data saved.
# Starting data collection for session 54 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 54 data saved.
# Starting data collection for session 55 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 55 data saved.
# Starting data collection for session 56 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 56 data saved.
# Starting data collection for session 57 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 57 data saved.
# Starting data collection for session 58 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 58 data saved.
# Starting data collection for session 59 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 59 data saved.
# Starting data collection for session 60 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 60 data saved.
# Starting data collection for session 61 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 61 data saved.
# Starting data collection for session 62 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 62 data saved.
# Starting data collection for session 63 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 63 data saved.
# Starting data collection for session 64 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 64 data saved.
# Starting data collection for session 65 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 65 data saved.
# Starting data collection for session 66 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 66 data saved.
# Starting data collection for session 67 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 67 data saved.
# Starting data collection for session 68 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 68 data saved.
# Starting data collection for session 69 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 69 data saved.
# Starting data collection for session 70 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 70 data saved.
# Starting data collection for session 71 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 71 data saved.
# Starting data collection for session 72 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 72 data saved.
# Starting data collection for session 73 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 73 data saved.
# Starting data collection for session 74 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 74 data saved.
# Starting data collection for session 75 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 75 data saved.
# Starting data collection for session 76 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 76 data saved.
# Starting data collection for session 77 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 77 data saved.
# Starting data collection for session 78 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 78 data saved.
# Starting data collection for session 79 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 79 data saved.
# Starting data collection for session 80 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 80 data saved.
# Starting data collection for session 81 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 81 data saved.
# Starting data collection for session 82 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 82 data saved.
# Starting data collection for session 83 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 83 data saved.
# Starting data collection for session 84 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 84 data saved.
# Starting data collection for session 85 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 85 data saved.
# Starting data collection for session 86 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 86 data saved.
# Starting data collection for session 87 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 87 data saved.
# Starting data collection for session 88 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 88 data saved.
# Starting data collection for session 89 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 89 data saved.
# Starting data collection for session 90 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 90 data saved.
# Starting data collection for session 91 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 91 data saved.
# Starting data collection for session 92 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 92 data saved.
# Starting data collection for session 93 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 93 data saved.
# Starting data collection for session 94 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 94 data saved.
# Starting data collection for session 95 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 95 data saved.
# Starting data collection for session 96 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 96 data saved.
# Starting data collection for session 97 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 97 data saved.
# Starting data collection for session 98 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 98 data saved.
# Starting data collection for session 99 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 99 data saved.
# Starting data collection for session 100 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 100 data saved.
# Starting data collection for session 101 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 101 data saved.
# Starting data collection for session 102 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 102 data saved.
# Starting data collection for session 103 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 103 data saved.
# Starting data collection for session 104 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 104 data saved.
# Starting data collection for session 105 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 105 data saved.
# Starting data collection for session 106 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 106 data saved.
# Starting data collection for session 107 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 107 data saved.
# Starting data collection for session 108 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 108 data saved.
# Starting data collection for session 109 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 109 data saved.
# Starting data collection for session 110 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 110 data saved.
# Starting data collection for session 111 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 111 data saved.
# Starting data collection for session 112 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 112 data saved.
# Starting data collection for session 113 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 113 data saved.
# Starting data collection for session 114 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 114 data saved.
# Starting data collection for session 115 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 115 data saved.
# Starting data collection for session 116 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 116 data saved.
# Starting data collection for session 117 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 117 data saved.
# Starting data collection for session 118 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 118 data saved.
# Starting data collection for session 119 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 119 data saved.
# Starting data collection for session 120 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 120 data saved.
# Starting data collection for session 121 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 121 data saved.
# Starting data collection for session 122 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 122 data saved.
# Starting data collection for session 123 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 123 data saved.
# Starting data collection for session 124 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 124 data saved.
# Starting data collection for session 125 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 125 data saved.
# Starting data collection for session 126 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 126 data saved.
# Starting data collection for session 127 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 127 data saved.
# Starting data collection for session 128 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 128 data saved.
# Starting data collection for session 129 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 129 data saved.
# Starting data collection for session 130 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 130 data saved.
# Starting data collection for session 131 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 131 data saved.
# Starting data collection for session 132 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 132 data saved.
# Starting data collection for session 133 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 133 data saved.
# Starting data collection for session 134 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 134 data saved.
# Starting data collection for session 135 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 135 data saved.
# Starting data collection for session 136 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 136 data saved.
# Starting data collection for session 137 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 137 data saved.
# Starting data collection for session 138 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 138 data saved.
# Starting data collection for session 139 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 139 data saved.
# Starting data collection for session 140 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 140 data saved.
# Starting data collection for session 141 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 141 data saved.
# Starting data collection for session 142 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 142 data saved.
# Starting data collection for session 143 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 143 data saved.
# Starting data collection for session 144 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 144 data saved.
# Starting data collection for session 145 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 145 data saved.
# Starting data collection for session 146 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 146 data saved.
# Starting data collection for session 147 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 147 data saved.
# Starting data collection for session 148 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 148 data saved.
# Starting data collection for session 149 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 149 data saved.
# Starting data collection for session 150 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 150 data saved.
# Starting data collection for session 151 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 151 data saved.
# Starting data collection for session 152 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 152 data saved.
# Starting data collection for session 153 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 153 data saved.
# Starting data collection for session 154 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 154 data saved.
# Starting data collection for session 155 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 155 data saved.
# Starting data collection for session 156 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 156 data saved.
# Starting data collection for session 157 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 157 data saved.
# Starting data collection for session 158 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 158 data saved.
# Starting data collection for session 159 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 159 data saved.
# Starting data collection for session 160 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 160 data saved.
# Starting data collection for session 161 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 161 data saved.
# Starting data collection for session 162 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 162 data saved.
# Starting data collection for session 163 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 163 data saved.
# Starting data collection for session 164 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 164 data saved.
# Starting data collection for session 165 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 165 data saved.
# Starting data collection for session 166 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 166 data saved.
# Starting data collection for session 167 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 167 data saved.
# Starting data collection for session 168 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 168 data saved.
# Starting data collection for session 169 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 169 data saved.
# Starting data collection for session 170 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 170 data saved.
# Starting data collection for session 171 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 171 data saved.
# Starting data collection for session 172 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 172 data saved.
# Starting data collection for session 173 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 173 data saved.
# Starting data collection for session 174 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 174 data saved.
# Starting data collection for session 175 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 175 data saved.
# Starting data collection for session 176 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 176 data saved.
# Starting data collection for session 177 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 177 data saved.
# Starting data collection for session 178 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 178 data saved.
# Starting data collection for session 179 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 179 data saved.
# Starting data collection for session 180 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 180 data saved.
# Starting data collection for session 181 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 181 data saved.
# Starting data collection for session 182 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 182 data saved.
# Starting data collection for session 183 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 183 data saved.
# Starting data collection for session 184 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 184 data saved.
# Starting data collection for session 185 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 185 data saved.
# Starting data collection for session 186 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 186 data saved.
# Starting data collection for session 187 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 187 data saved.
# Starting data collection for session 188 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 188 data saved.
# Starting data collection for session 189 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 189 data saved.
# Starting data collection for session 190 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 190 data saved.
# Starting data collection for session 191 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 191 data saved.
# Starting data collection for session 192 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 192 data saved.
# Starting data collection for session 193 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 193 data saved.
# Starting data collection for session 194 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 194 data saved.
# Starting data collection for session 195 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 195 data saved.
# Starting data collection for session 196 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 196 data saved.
# Starting data collection for session 197 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 197 data saved.
# Starting data collection for session 198 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 198 data saved.
# Starting data collection for session 199 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 199 data saved.
# Starting data collection for session 200 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 200 data saved.
# Starting data collection for session 201 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 201 data saved.
# Starting data collection for session 202 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 202 data saved.
# Starting data collection for session 203 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 203 data saved.
# Starting data collection for session 204 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 204 data saved.
# Starting data collection for session 205 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 205 data saved.
# Starting data collection for session 206 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 206 data saved.
# Starting data collection for session 207 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 207 data saved.
# Starting data collection for session 208 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 208 data saved.
# Starting data collection for session 209 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 209 data saved.
# Starting data collection for session 210 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 210 data saved.
# Starting data collection for session 211 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 211 data saved.
# Starting data collection for session 212 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 212 data saved.
# Starting data collection for session 213 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 213 data saved.
# Starting data collection for session 214 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 214 data saved.
# Starting data collection for session 215 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 215 data saved.
# Starting data collection for session 216 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 216 data saved.
# Starting data collection for session 217 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 217 data saved.
# Starting data collection for session 218 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 218 data saved.
# Starting data collection for session 219 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 219 data saved.
# Starting data collection for session 220 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 220 data saved.
# Starting data collection for session 221 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 221 data saved.
# Starting data collection for session 222 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 222 data saved.
# Starting data collection for session 223 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 223 data saved.
# Starting data collection for session 224 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 224 data saved.
# Starting data collection for session 225 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 225 data saved.
# Starting data collection for session 226 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 226 data saved.
# Starting data collection for session 227 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 227 data saved.
# Starting data collection for session 228 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 228 data saved.
# Starting data collection for session 229 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 229 data saved.
# Starting data collection for session 230 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 230 data saved.
# Starting data collection for session 231 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 231 data saved.
# Starting data collection for session 232 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 232 data saved.
# Starting data collection for session 233 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 233 data saved.
# Starting data collection for session 234 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 234 data saved.
# Starting data collection for session 235 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 235 data saved.
# Starting data collection for session 236 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 236 data saved.
# Starting data collection for session 237 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 237 data saved.
# Starting data collection for session 238 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 238 data saved.
# Starting data collection for session 239 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 239 data saved.
# Starting data collection for session 240 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 240 data saved.
# Starting data collection for session 241 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 241 data saved.
# Starting data collection for session 242 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 242 data saved.
# Starting data collection for session 243 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 243 data saved.
# Starting data collection for session 244 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 244 data saved.
# Starting data collection for session 245 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 245 data saved.
# Starting data collection for session 246 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 246 data saved.
# Starting data collection for session 247 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 247 data saved.
# Starting data collection for session 248 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 248 data saved.
# Starting data collection for session 249 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 249 data saved.
# Starting data collection for session 250 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 250 data saved.
# Starting data collection for session 251 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 251 data saved.
# Starting data collection for session 252 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 252 data saved.
# Starting data collection for session 253 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 253 data saved.
# Starting data collection for session 254 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 254 data saved.
# Starting data collection for session 255 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 255 data saved.
# Starting data collection for session 256 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 256 data saved.
# Starting data collection for session 257 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 257 data saved.
# Starting data collection for session 258 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 258 data saved.
# Starting data collection for session 259 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 259 data saved.
# Starting data collection for session 260 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 260 data saved.
# Starting data collection for session 261 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 261 data saved.
# Starting data collection for session 262 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 262 data saved.
# Starting data collection for session 263 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 263 data saved.
# Starting data collection for session 264 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 264 data saved.
# Starting data collection for session 265 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 265 data saved.
# Starting data collection for session 266 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 266 data saved.
# Starting data collection for session 267 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 267 data saved.
# Starting data collection for session 268 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 268 data saved.
# Starting data collection for session 269 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 269 data saved.
# Starting data collection for session 270 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 270 data saved.
# Starting data collection for session 271 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 271 data saved.
# Starting data collection for session 272 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 272 data saved.
# Starting data collection for session 273 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 273 data saved.
# Starting data collection for session 274 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 274 data saved.
# Starting data collection for session 275 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 275 data saved.
# Starting data collection for session 276 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 276 data saved.
# Starting data collection for session 277 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 277 data saved.
# Starting data collection for session 278 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 278 data saved.
# Starting data collection for session 279 with label 'alexa_standby'
# Red Pitaya configured successfully.
# Session 279 data saved.
# Starting data collection for session 280 with label 'alexa_standby'
# Red Pitaya configured successfully.
#
# Data collection stopped by user.
# Data collection terminated. Last session index: 279
