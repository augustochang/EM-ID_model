# %% [markdown]
# # signal processing types
# ## single folder one by one with config

# %%
import os
import json
import pandas as pd
import numpy as np
import re
from scipy import stats
from scipy.signal import welch

# ---------------------------
# Configuration and Setup
# ---------------------------

def load_config(config_path='config.json'):
    """
    Load configuration parameters from a JSON file.
    """
    if not os.path.exists(config_path):
        raise FileNotFoundError(f"Configuration file '{config_path}' not found.")
    
    with open(config_path, 'r') as f:
        config = json.load(f)
    
    required_keys = ['base_dir', 'device_label', 'processing_method']
    for key in required_keys:
        if key not in config:
            raise KeyError(f"Missing required configuration key: '{key}'")
    
    if config['processing_method'].lower() not in ['fft', 'welch', 'bd']:
        raise ValueError(f"Invalid processing_method '{config['processing_method']}'. Must be 'fft', 'welch', or 'bd'.")
    
    return config

# ---------------------------
# Statistical Feature Computation
# ---------------------------

def compute_statistical_features(power_dbm):
    """
    Compute the required statistical features from power_dbm.
    """
    features = {}
    try:
        features['entropy'] = stats.entropy(np.abs(power_dbm))
        features['skewness'] = stats.skew(power_dbm)
        features['interquartile_range'] = np.percentile(power_dbm, 75) - np.percentile(power_dbm, 25)
        features['kurtosis'] = stats.kurtosis(power_dbm)
        features['percentile_75'] = np.percentile(power_dbm, 75)
        features['range'] = np.ptp(power_dbm)
        features['maximum'] = np.max(power_dbm)
        features['median'] = np.median(power_dbm)
        features['percentile_90'] = np.percentile(power_dbm, 90)
        features['mean_absolute_deviation'] = np.mean(np.abs(power_dbm - np.mean(power_dbm)))
    except Exception as e:
        print(f"Error computing statistical features: {e}")
        features = {key: np.nan for key in ['entropy', 'skewness', 'interquartile_range', 'kurtosis',
                                           'percentile_75', 'range', 'maximum', 'median',
                                           'percentile_90', 'mean_absolute_deviation']}
    return features

# ---------------------------
# Session Processing
# ---------------------------

def process_session(ch1_filepath, ch2_filepath, decimation_factor, processing_method):
    """
    Process a single session by computing features for CH1 and CH2 using the specified processing method.
    Returns a dictionary with all required information.
    """
    session_data = {}
    try:
        # Extract session number from filename
        session_match = re.search(r'session_(\d{3})_CH1\.csv', os.path.basename(ch1_filepath))
        if not session_match:
            print(f"Invalid CH1 filename format: {ch1_filepath}")
            return None
        session_number = int(session_match.group(1))
        session_data['session'] = session_number
        
        # Extract date from filepath
        # Assuming the path is base_dir/device_label/YYYY-MM-DD/session_###_CHx.csv
        date_str = os.path.basename(os.path.dirname(ch1_filepath))
        session_data['date'] = date_str
        
        # Read CH1 data
        df_ch1 = pd.read_csv(ch1_filepath)
        if df_ch1.empty or 'voltage' not in df_ch1.columns:
            print(f"No data or missing 'voltage' column in {ch1_filepath}")
            return None
        
        # Handle NaN values in CH1
        if df_ch1['voltage'].isnull().any():
            print(f"NaN values found in {ch1_filepath}. They will be ignored.")
            df_ch1 = df_ch1.dropna(subset=['voltage'])
            if df_ch1.empty:
                print(f"All data is NaN in {ch1_filepath}. Skipping session.")
                return None
        
        # Get the first timestamp as session timestamp
        timestamp_str = df_ch1['timestamp'].iloc[0]
        session_data['timestamp'] = timestamp_str
        
        # Process CH1
        signal_ch1 = df_ch1['voltage'].values
        signal_ch1 = signal_ch1 - np.mean(signal_ch1)  # Remove DC component

        if processing_method.lower() == 'welch':
            frequencies_ch1, power_spectrum_ch1 = welch(signal_ch1, fs=125e6 / decimation_factor, nperseg=1024)
        elif processing_method.lower() == 'fft':
            # Using FFT
            N = len(signal_ch1)
            frequencies_ch1 = np.fft.fftfreq(N, d=1/(125e6 / decimation_factor))
            power_spectrum_ch1 = np.abs(np.fft.fft(signal_ch1))**2 / N
        elif processing_method.lower() == 'bd':
            # Placeholder for Blind Deconvolution
            # Implement blind deconvolution here
            # For demonstration, we'll use the same as Welch
            frequencies_ch1, power_spectrum_ch1 = welch(signal_ch1, fs=125e6 / decimation_factor, nperseg=1024)
        else:
            raise ValueError(f"Invalid processing method: {processing_method}")
        
        # Avoid log of zero by replacing zeros with a very small number
        power_spectrum_ch1 = np.where(power_spectrum_ch1 == 0, 1e-12, power_spectrum_ch1)
        power_dbm_ch1 = 10 * np.log10(power_spectrum_ch1 / 50)  # Assuming 50 ohm impedance
        mask_ch1 = (frequencies_ch1 >= 10e3) & (frequencies_ch1 <= 100e3)
        filtered_power_dbm_ch1 = power_dbm_ch1[mask_ch1]
        features_ch1 = compute_statistical_features(filtered_power_dbm_ch1)
        
        # Add CH1 features to session data
        for key, value in features_ch1.items():
            session_data[f'ch1_{key}'] = value
        
        # Read CH2 data
        df_ch2 = pd.read_csv(ch2_filepath)
        if df_ch2.empty or 'voltage' not in df_ch2.columns:
            print(f"No data or missing 'voltage' column in {ch2_filepath}")
            return None
        
        # Handle NaN values in CH2
        if df_ch2['voltage'].isnull().any():
            print(f"NaN values found in {ch2_filepath}. They will be ignored.")
            df_ch2 = df_ch2.dropna(subset=['voltage'])
            if df_ch2.empty:
                print(f"All data is NaN in {ch2_filepath}. Skipping session.")
                return None
        
        # Process CH2
        signal_ch2 = df_ch2['voltage'].values
        signal_ch2 = signal_ch2 - np.mean(signal_ch2)  # Remove DC component

        if processing_method.lower() == 'welch':
            frequencies_ch2, power_spectrum_ch2 = welch(signal_ch2, fs=125e6 / decimation_factor, nperseg=1024)
        elif processing_method.lower() == 'fft':
            # Using FFT
            N = len(signal_ch2)
            frequencies_ch2 = np.fft.fftfreq(N, d=1/(125e6 / decimation_factor))
            power_spectrum_ch2 = np.abs(np.fft.fft(signal_ch2))**2 / N
        elif processing_method.lower() == 'bd':
            # Placeholder for Blind Deconvolution
            # Implement blind deconvolution here
            # For demonstration, we'll use the same as Welch
            frequencies_ch2, power_spectrum_ch2 = welch(signal_ch2, fs=125e6 / decimation_factor, nperseg=1024)
        else:
            raise ValueError(f"Invalid processing method: {processing_method}")
        
        # Avoid log of zero by replacing zeros with a very small number
        power_spectrum_ch2 = np.where(power_spectrum_ch2 == 0, 1e-12, power_spectrum_ch2)
        power_dbm_ch2 = 10 * np.log10(power_spectrum_ch2 / 50)  # Assuming 50 ohm impedance
        mask_ch2 = (frequencies_ch2 >= 10e3) & (frequencies_ch2 <= 100e3)
        filtered_power_dbm_ch2 = power_dbm_ch2[mask_ch2]
        features_ch2 = compute_statistical_features(filtered_power_dbm_ch2)
        
        # Add CH2 features to session data
        for key, value in features_ch2.items():
            session_data[f'ch2_{key}'] = value
        
    except Exception as e:
        print(f"Error processing session {ch1_filepath} and {ch2_filepath}: {e}")
        return None
    
    return session_data

# ---------------------------
# Main Processing Function
# ---------------------------

def main():
    # Load configuration
    try:
        config = load_config('config.json')
    except (FileNotFoundError, KeyError, ValueError) as e:
        print(f"Configuration Error: {e}")
        return
    
    base_dir = config['base_dir']
    device_label = config['device_label']
    processing_method = config['processing_method']
    decimation_factor = config.get('decimation_factor', 1024)  # Default to 1024 if not specified
    
    # Initialize a list to collect session data
    summary_data = []
    
    # Traverse the directory structure
    device_dir_path = os.path.join(base_dir, device_label)
    if not os.path.exists(device_dir_path):
        print(f"Device directory '{device_dir_path}' does not exist.")
        return
    
    # Iterate over date directories
    for date_dir in sorted(os.listdir(device_dir_path)):
        date_dir_path = os.path.join(device_dir_path, date_dir)
        if not os.path.isdir(date_dir_path):
            continue  # Skip if not a directory
        
        print(f"Processing date directory: {date_dir_path}")
        
        # Find all session_###_CH1.csv files
        session_pattern = re.compile(r'session_(\d{3})_CH1\.csv')
        for filename in sorted(os.listdir(date_dir_path)):
            match = session_pattern.match(filename)
            if match:
                session_number = match.group(1)
                ch1_filepath = os.path.join(date_dir_path, filename)
                ch2_filename = f'session_{session_number}_CH2.csv'
                ch2_filepath = os.path.join(date_dir_path, ch2_filename)
                
                # Check if CH2 file exists
                if not os.path.exists(ch2_filepath):
                    print(f"Missing CH2 file for session {session_number} in {date_dir_path}")
                    continue
                
                print(f"Processing session {session_number}")
                
                # Process the session
                session_data = process_session(ch1_filepath, ch2_filepath, decimation_factor, processing_method)
                if session_data:
                    session_data['device_label'] = device_label
                    summary_data.append(session_data)
                    print(f"Session {session_number} processed successfully.")
                else:
                    print(f"Failed to process session {session_number} in {date_dir_path}")
    
    # Convert the list of dictionaries to a DataFrame
    summary_df = pd.DataFrame(summary_data, columns=[
        'date', 'timestamp', 'session',
        'ch1_entropy', 'ch1_skewness', 'ch1_interquartile_range',
        'ch1_kurtosis', 'ch1_percentile_75', 'ch1_range',
        'ch1_maximum', 'ch1_median', 'ch1_percentile_90',
        'ch1_mean_absolute_deviation',
        'ch2_entropy', 'ch2_skewness', 'ch2_interquartile_range',
        'ch2_kurtosis', 'ch2_percentile_75', 'ch2_range',
        'ch2_maximum', 'ch2_median', 'ch2_percentile_90',
        'ch2_mean_absolute_deviation',
        'device_label'
    ])
    
    # Define the output summary CSV path
    output_summary_path = os.path.join(base_dir, device_label, f'summary_features_{processing_method.lower()}.csv')
    
    # Save the summary DataFrame to CSV
    try:
        summary_df.to_csv(output_summary_path, index=False)
        print(f"Summary CSV successfully saved to {output_summary_path}")
    except Exception as e:
        print(f"Failed to save summary CSV: {e}")

# ---------------------------
# Entry Point
# ---------------------------

if __name__ == "__main__":
    main()
# Out:
# Processing date directory: /Volumes/One Touch/data/ipad_augusto|mac_luca/2024-11-19
# Processing session 001
# Session 001 processed successfully.
# Processing session 002
# Session 002 processed successfully.
# Processing session 003
# Session 003 processed successfully.
# Processing session 004
# Session 004 processed successfully.
# Processing session 005
# Session 005 processed successfully.
# Processing session 006
# Session 006 processed successfully.
# Processing session 007
# Session 007 processed successfully.
# Processing session 008
# Session 008 processed successfully.
# Processing session 009
# Session 009 processed successfully.
# Processing session 010
# Session 010 processed successfully.
# Processing session 011
# Session 011 processed successfully.
# Processing session 012
# Session 012 processed successfully.
# Processing session 013
# Session 013 processed successfully.
# Processing session 014
# Session 014 processed successfully.
# Processing session 015
# Session 015 processed successfully.
# Processing session 016
# Session 016 processed successfully.
# Processing session 017
# Session 017 processed successfully.
# Processing session 018
# Session 018 processed successfully.
# Processing session 019
# Session 019 processed successfully.
# Processing session 020
# Session 020 processed successfully.
# Processing session 021
# Session 021 processed successfully.
# Processing session 022
# Session 022 processed successfully.
# Processing session 023
# Session 023 processed successfully.
# Processing session 024
# Session 024 processed successfully.
# Processing session 025
# Session 025 processed successfully.
# Processing session 026
# Session 026 processed successfully.
# Processing session 027
# Session 027 processed successfully.
# Processing session 028
# Session 028 processed successfully.
# Processing session 029
# Session 029 processed successfully.
# Processing session 030
# Session 030 processed successfully.
# Processing session 031
# Session 031 processed successfully.
# Processing session 032
# Session 032 processed successfully.
# Processing session 033
# Session 033 processed successfully.
# Processing session 034
# Session 034 processed successfully.
# Processing session 035
# Session 035 processed successfully.
# Processing session 036
# Session 036 processed successfully.
# Processing session 037
# Session 037 processed successfully.
# Processing session 038
# Session 038 processed successfully.
# Processing session 039
# Session 039 processed successfully.
# Processing session 040
# Session 040 processed successfully.
# Processing session 041
# Session 041 processed successfully.
# Processing session 042
# Session 042 processed successfully.
# Processing session 043
# Session 043 processed successfully.
# Processing session 044
# Session 044 processed successfully.
# Processing session 045
# Session 045 processed successfully.
# Processing session 046
# Session 046 processed successfully.
# Processing session 047
# Session 047 processed successfully.
# Processing session 048
# Session 048 processed successfully.
# Processing session 049
# Session 049 processed successfully.
# Processing session 050
# Session 050 processed successfully.
# Processing session 051
# Session 051 processed successfully.
# Processing session 052
# Session 052 processed successfully.
# Processing session 053
# Session 053 processed successfully.
# Processing session 054
# Session 054 processed successfully.
# Processing session 055
# Session 055 processed successfully.
# Processing session 056
# Session 056 processed successfully.
# Processing session 057
# Session 057 processed successfully.
# Processing session 058
# Session 058 processed successfully.
# Processing session 059
# Session 059 processed successfully.
# Processing session 060
# Session 060 processed successfully.
# Processing session 061
# Session 061 processed successfully.
# Processing session 062
# Session 062 processed successfully.
# Processing session 063
# Session 063 processed successfully.
# Processing session 064
# Session 064 processed successfully.
# Processing session 065
# Session 065 processed successfully.
# Processing session 066
# Session 066 processed successfully.
# Processing session 067
# Session 067 processed successfully.
# Processing session 068
# Session 068 processed successfully.
# Processing session 069
# Session 069 processed successfully.
# Processing session 070
# Session 070 processed successfully.
# Processing session 071
# Session 071 processed successfully.
# Processing session 072
# Session 072 processed successfully.
# Processing session 073
# Session 073 processed successfully.
# Processing session 074
# Session 074 processed successfully.
# Processing session 075
# Session 075 processed successfully.
# Processing session 076
# Session 076 processed successfully.
# Processing session 077
# Session 077 processed successfully.
# Processing session 078
# Session 078 processed successfully.
# Processing session 079
# Session 079 processed successfully.
# Processing session 080
# Session 080 processed successfully.
# Processing session 081
# Session 081 processed successfully.
# Processing session 082
# Session 082 processed successfully.
# Processing session 083
# Session 083 processed successfully.
# Processing session 084
# Session 084 processed successfully.
# Processing session 085
# Session 085 processed successfully.
# Processing session 086
# Session 086 processed successfully.
# Processing session 087
# Session 087 processed successfully.
# Processing session 088
# Session 088 processed successfully.
# Processing session 089
# Session 089 processed successfully.
# Processing session 090
# Session 090 processed successfully.
# Processing session 091
# Session 091 processed successfully.
# Processing session 092
# Session 092 processed successfully.
# Processing session 093
# Session 093 processed successfully.
# Processing session 094
# Session 094 processed successfully.
# Processing session 095
# Session 095 processed successfully.
# Processing session 096
# Session 096 processed successfully.
# Processing session 097
# Session 097 processed successfully.
# Processing session 098
# Session 098 processed successfully.
# Processing session 099
# Session 099 processed successfully.
# Processing session 100
# Session 100 processed successfully.
# Processing session 101
# Session 101 processed successfully.
# Processing session 102
# Session 102 processed successfully.
# Processing session 103
# Session 103 processed successfully.
# Processing session 104
# Session 104 processed successfully.
# Processing session 105
# Session 105 processed successfully.
# Processing session 106
# Session 106 processed successfully.
# Processing session 107
# Session 107 processed successfully.
# Processing session 108
# Session 108 processed successfully.
# Processing session 109
# Session 109 processed successfully.
# Processing session 110
# Session 110 processed successfully.
# Processing session 111
# Session 111 processed successfully.
# Processing session 112
# Session 112 processed successfully.
# Processing session 113
# Session 113 processed successfully.
# Processing session 114
# Session 114 processed successfully.
# Processing session 115
# Session 115 processed successfully.
# Processing session 116
# Session 116 processed successfully.
# Processing session 117
# Session 117 processed successfully.
# Processing session 118
# Session 118 processed successfully.
# Processing session 119
# Session 119 processed successfully.
# Processing session 120
# Session 120 processed successfully.
# Processing session 121
# Session 121 processed successfully.
# Processing session 122
# Session 122 processed successfully.
# Processing session 123
# Session 123 processed successfully.
# Processing session 124
# Session 124 processed successfully.
# Processing session 125
# Session 125 processed successfully.
# Processing session 126
# Session 126 processed successfully.
# Processing session 127
# Session 127 processed successfully.
# Processing session 128
# Session 128 processed successfully.
# Processing session 129
# Session 129 processed successfully.
# Processing session 130
# Session 130 processed successfully.
# Processing session 131
# Session 131 processed successfully.
# Processing session 132
# Session 132 processed successfully.
# Processing session 133
# Session 133 processed successfully.
# Processing session 134
# Session 134 processed successfully.
# Processing session 135
# Session 135 processed successfully.
# Processing session 136
# Session 136 processed successfully.
# Processing session 137
# Session 137 processed successfully.
# Processing session 138
# Session 138 processed successfully.
# Processing session 139
# Session 139 processed successfully.
# Processing session 140
# Session 140 processed successfully.
# Processing session 141
# Session 141 processed successfully.
# Processing session 142
# Session 142 processed successfully.
# Processing session 143
# Session 143 processed successfully.
# Processing session 144
# Session 144 processed successfully.
# Processing session 145
# Session 145 processed successfully.
# Processing session 146
# Session 146 processed successfully.
# Processing session 147
# Session 147 processed successfully.
# Processing session 148
# Session 148 processed successfully.
# Processing session 149
# Session 149 processed successfully.
# Processing session 150
# Session 150 processed successfully.
# Processing session 151
# Session 151 processed successfully.
# Processing session 152
# Session 152 processed successfully.
# Processing session 153
# Session 153 processed successfully.
# Processing session 154
# Session 154 processed successfully.
# Processing session 155
# Session 155 processed successfully.
# Processing session 156
# Session 156 processed successfully.
# Processing session 157
# Session 157 processed successfully.
# Processing session 158
# Session 158 processed successfully.
# Processing session 159
# Session 159 processed successfully.
# Processing session 160
# Session 160 processed successfully.
# Processing session 161
# Session 161 processed successfully.
# Processing session 162
# Session 162 processed successfully.
# Processing session 163
# Session 163 processed successfully.
# Processing session 164
# Session 164 processed successfully.
# Processing session 165
# Session 165 processed successfully.
# Processing session 166
# Session 166 processed successfully.
# Processing session 167
# Session 167 processed successfully.
# Processing session 168
# Session 168 processed successfully.
# Processing session 169
# Session 169 processed successfully.
# Processing session 170
# Session 170 processed successfully.
# Processing session 171
# Session 171 processed successfully.
# Processing session 172
# Session 172 processed successfully.
# Processing session 173
# Session 173 processed successfully.
# Processing session 174
# Session 174 processed successfully.
# Processing session 175
# Session 175 processed successfully.
# Processing session 176
# Session 176 processed successfully.
# Processing session 177
# Session 177 processed successfully.
# Processing session 178
# Session 178 processed successfully.
# Processing session 179
# Session 179 processed successfully.
# Processing session 180
# Session 180 processed successfully.
# Processing session 181
# Session 181 processed successfully.
# Processing session 182
# Session 182 processed successfully.
# Processing session 183
# Session 183 processed successfully.
# Processing session 184
# Session 184 processed successfully.
# Processing session 185
# Session 185 processed successfully.
# Processing session 186
# Session 186 processed successfully.
# Processing session 187
# Session 187 processed successfully.
# Processing session 188
# Session 188 processed successfully.
# Processing session 189
# Session 189 processed successfully.
# Processing session 190
# Session 190 processed successfully.
# Processing session 191
# Session 191 processed successfully.
# Processing session 192
# Session 192 processed successfully.
# Processing session 193
# Session 193 processed successfully.
# Processing session 194
# Session 194 processed successfully.
# Processing session 195
# Session 195 processed successfully.
# Processing session 196
# Session 196 processed successfully.
# Processing session 197
# Session 197 processed successfully.
# Processing session 198
# Session 198 processed successfully.
# Processing session 199
# Session 199 processed successfully.
# Processing session 200
# Session 200 processed successfully.
# Processing session 201
# Session 201 processed successfully.
# Processing session 202
# Session 202 processed successfully.
# Processing session 203
# Session 203 processed successfully.
# Processing session 204
# Session 204 processed successfully.
# Processing session 205
# Session 205 processed successfully.
# Processing session 206
# Session 206 processed successfully.
# Processing session 207
# Session 207 processed successfully.
# Processing session 208
# Session 208 processed successfully.
# Processing session 209
# Session 209 processed successfully.
# Processing session 210
# Session 210 processed successfully.
# Processing session 211
# Session 211 processed successfully.
# Processing session 212
# Session 212 processed successfully.
# Processing session 213
# Session 213 processed successfully.
# Processing session 214
# Session 214 processed successfully.
# Processing session 215
# Session 215 processed successfully.
# Processing session 216
# Session 216 processed successfully.
# Processing session 217
# Session 217 processed successfully.
# Processing session 218
# Session 218 processed successfully.
# Processing session 219
# Session 219 processed successfully.
# Processing session 220
# Session 220 processed successfully.
# Processing session 221
# Session 221 processed successfully.
# Processing session 222
# Session 222 processed successfully.
# Processing session 223
# Session 223 processed successfully.
# Processing session 224
# Session 224 processed successfully.
# Processing session 225
# Session 225 processed successfully.
# Processing session 226
# Session 226 processed successfully.
# Processing session 227
# Session 227 processed successfully.
# Processing session 228
# Session 228 processed successfully.
# Processing session 229
# Session 229 processed successfully.
# Processing session 230
# Session 230 processed successfully.
# Processing session 231
# Session 231 processed successfully.
# Processing session 232
# Session 232 processed successfully.
# Processing session 233
# Session 233 processed successfully.
# Processing session 234
# Session 234 processed successfully.
# Processing session 235
# Session 235 processed successfully.
# Processing session 236
# Session 236 processed successfully.
# Processing session 237
# Session 237 processed successfully.
# Processing session 238
# Session 238 processed successfully.
# Processing session 239
# Session 239 processed successfully.
# Processing session 240
# Session 240 processed successfully.
# Processing session 241
# Session 241 processed successfully.
# Processing session 242
# Session 242 processed successfully.
# Processing session 243
# Session 243 processed successfully.
# Processing session 244
# Session 244 processed successfully.
# Processing session 245
# Session 245 processed successfully.
# Processing session 246
# Session 246 processed successfully.
# Processing session 247
# Session 247 processed successfully.
# Processing session 248
# Session 248 processed successfully.
# Processing session 249
# Session 249 processed successfully.
# Processing session 250
# Session 250 processed successfully.
# Processing session 251
# Session 251 processed successfully.
# Processing session 252
# Session 252 processed successfully.
# Processing session 253
# Session 253 processed successfully.
# Processing session 254
# Session 254 processed successfully.
# Processing session 255
# Session 255 processed successfully.
# Processing session 256
# Session 256 processed successfully.
# Processing session 257
# Session 257 processed successfully.
# Processing session 258
# Session 258 processed successfully.
# Processing session 259
# Session 259 processed successfully.
# Processing session 260
# Session 260 processed successfully.
# Processing session 261
# Session 261 processed successfully.
# Processing session 262
# Session 262 processed successfully.
# Processing session 263
# Session 263 processed successfully.
# Processing session 264
# Session 264 processed successfully.
# Processing session 265
# Session 265 processed successfully.
# Processing session 266
# Session 266 processed successfully.
# Processing session 267
# Session 267 processed successfully.
# Processing session 268
# Session 268 processed successfully.
# Processing session 269
# Session 269 processed successfully.
# Processing session 270
# Session 270 processed successfully.
# Processing session 271
# Session 271 processed successfully.
# Processing session 272
# Session 272 processed successfully.
# Processing session 273
# Session 273 processed successfully.
# Processing session 274
# Session 274 processed successfully.
# Processing session 275
# Session 275 processed successfully.
# Processing session 276
# Session 276 processed successfully.
# Processing session 277
# Session 277 processed successfully.
# Processing session 278
# Session 278 processed successfully.
# Processing session 279
# Session 279 processed successfully.
# Processing session 280
# Session 280 processed successfully.
# Processing session 281
# Session 281 processed successfully.
# Processing session 282
# Session 282 processed successfully.
# Processing session 283
# Session 283 processed successfully.
# Processing session 284
# Session 284 processed successfully.
# Processing session 285
# Session 285 processed successfully.
# Processing session 286
# Session 286 processed successfully.
# Processing session 287
# Session 287 processed successfully.
# Processing session 288
# Session 288 processed successfully.
# Processing session 289
# Session 289 processed successfully.
# Processing session 290
# Session 290 processed successfully.
# Processing session 291
# Session 291 processed successfully.
# Processing session 292
# Session 292 processed successfully.
# Processing session 293
# Session 293 processed successfully.
# Processing session 294
# Session 294 processed successfully.
# Processing session 295
# Session 295 processed successfully.
# Processing session 296
# Session 296 processed successfully.
# Processing session 297
# Session 297 processed successfully.
# Processing session 298
# Session 298 processed successfully.
# Processing session 299
# Session 299 processed successfully.
# Processing session 300
# Session 300 processed successfully.
# Processing session 301
# Session 301 processed successfully.
# Processing session 302
# Session 302 processed successfully.
# Processing session 303
# Session 303 processed successfully.
# Processing session 304
# Session 304 processed successfully.
# Processing session 305
# Session 305 processed successfully.
# Processing session 306
# Session 306 processed successfully.
# Processing session 307
# Session 307 processed successfully.
# Processing session 308
# Session 308 processed successfully.
# Processing session 309
# Session 309 processed successfully.
# Processing session 310
# Session 310 processed successfully.
# Processing session 311
# Session 311 processed successfully.
# Processing session 312
# Session 312 processed successfully.
# Processing session 313
# Session 313 processed successfully.
# Processing session 314
# Session 314 processed successfully.
# Processing session 315
# Session 315 processed successfully.
# Processing session 316
# Session 316 processed successfully.
# Processing session 317
# Session 317 processed successfully.
# Processing session 318
# Session 318 processed successfully.
# Processing session 319
# Session 319 processed successfully.
# Processing session 320
# Session 320 processed successfully.
# Processing session 321
# Session 321 processed successfully.
# Processing session 322
# Session 322 processed successfully.
# Processing session 323
# Session 323 processed successfully.
# Processing session 324
# Session 324 processed successfully.
# Processing session 325
# Session 325 processed successfully.
# Processing session 326
# Session 326 processed successfully.
# Processing session 327
# Session 327 processed successfully.
# Processing session 328
# Session 328 processed successfully.
# Processing session 329
# Session 329 processed successfully.
# Processing session 330
# Session 330 processed successfully.
# Processing session 331
# Session 331 processed successfully.
# Processing session 332
# Session 332 processed successfully.
# Processing session 333
# Session 333 processed successfully.
# Processing session 334
# Session 334 processed successfully.
# Processing session 335
# Session 335 processed successfully.
# Processing session 336
# Session 336 processed successfully.
# Processing session 337
# Session 337 processed successfully.
# Processing session 338
# Session 338 processed successfully.
# Processing session 339
# Session 339 processed successfully.
# Processing session 340
# Session 340 processed successfully.
# Processing session 341
# Session 341 processed successfully.
# Processing session 342
# Session 342 processed successfully.
# Processing session 343
# Session 343 processed successfully.
# Processing session 344
# Session 344 processed successfully.
# Processing session 345
# Session 345 processed successfully.
# Processing session 346
# Session 346 processed successfully.
# Processing session 347
# Session 347 processed successfully.
# Processing session 348
# Session 348 processed successfully.
# Processing session 349
# Session 349 processed successfully.
# Processing session 350
# Session 350 processed successfully.
# Processing session 351
# Session 351 processed successfully.
# Processing session 352
# Session 352 processed successfully.
# Processing session 353
# Session 353 processed successfully.
# Processing session 354
# Session 354 processed successfully.
# Processing session 355
# Session 355 processed successfully.
# Processing session 356
# Session 356 processed successfully.
# Processing session 357
# Session 357 processed successfully.
# Processing session 358
# Session 358 processed successfully.
# Processing session 359
# Session 359 processed successfully.
# Processing session 360
# Session 360 processed successfully.
# Processing session 361
# Session 361 processed successfully.
# Processing session 362
# Session 362 processed successfully.
# Processing session 363
# Session 363 processed successfully.
# Processing session 364
# Session 364 processed successfully.
# Processing session 365
# Session 365 processed successfully.
# Processing session 366
# Session 366 processed successfully.
# Processing session 367
# Session 367 processed successfully.
# Processing session 368
# Session 368 processed successfully.
# Processing session 369
# Session 369 processed successfully.
# Processing session 370
# Session 370 processed successfully.
# Processing session 371
# Session 371 processed successfully.
# Processing session 372
# Session 372 processed successfully.
# Processing session 373
# Session 373 processed successfully.
# Processing session 374
# Session 374 processed successfully.
# Processing session 375
# Session 375 processed successfully.
# Processing session 376
# Session 376 processed successfully.
# Processing session 377
# Session 377 processed successfully.
# Processing session 378
# Session 378 processed successfully.
# Processing session 379
# Session 379 processed successfully.
# Processing session 380
# Session 380 processed successfully.
# Processing session 381
# Session 381 processed successfully.
# Processing session 382
# Session 382 processed successfully.
# Processing session 383
# Session 383 processed successfully.
# Processing session 384
# Session 384 processed successfully.
# Processing session 385
# Session 385 processed successfully.
# Processing session 386
# Session 386 processed successfully.
# Processing session 387
# Session 387 processed successfully.
# Processing session 388
# Session 388 processed successfully.
# Processing session 389
# Session 389 processed successfully.
# Processing session 390
# Session 390 processed successfully.
# Processing session 391
# Session 391 processed successfully.
# Processing session 392
# Session 392 processed successfully.
# Processing session 393
# Session 393 processed successfully.
# Processing session 394
# Session 394 processed successfully.
# Processing session 395
# Session 395 processed successfully.
# Processing session 396
# Session 396 processed successfully.
# Processing session 397
# Session 397 processed successfully.
# Processing session 398
# Session 398 processed successfully.
# Processing session 399
# Session 399 processed successfully.
# Processing session 400
# Session 400 processed successfully.
# Processing session 401
# Session 401 processed successfully.
# Processing session 402
# Session 402 processed successfully.
# Processing session 403
# Session 403 processed successfully.
# Processing session 404
# Session 404 processed successfully.
# Processing session 405
# Session 405 processed successfully.
# Processing session 406
# Session 406 processed successfully.
# Processing session 407
# Session 407 processed successfully.
# Processing session 408
# Session 408 processed successfully.
# Processing session 409
# Session 409 processed successfully.
# Processing session 410
# Session 410 processed successfully.
# Processing session 411
# Session 411 processed successfully.
# Processing session 412
# Session 412 processed successfully.
# Processing session 413
# Session 413 processed successfully.
# Processing session 414
# Session 414 processed successfully.
# Processing session 415
# Session 415 processed successfully.
# Processing session 416
# Session 416 processed successfully.
# Processing session 417
# Session 417 processed successfully.
# Processing session 418
# Session 418 processed successfully.
# Processing session 419
# Session 419 processed successfully.
# Processing session 420
# Session 420 processed successfully.
# Processing session 421
# Session 421 processed successfully.
# Processing session 422
# Session 422 processed successfully.
# Processing session 423
# Session 423 processed successfully.
# Processing session 424
# Session 424 processed successfully.
# Processing session 425
# Session 425 processed successfully.
# Processing session 426
# Session 426 processed successfully.
# Processing session 427
# Session 427 processed successfully.
# Processing session 428
# Session 428 processed successfully.
# Processing session 429
# Session 429 processed successfully.
# Processing session 430
# Session 430 processed successfully.
# Processing session 431
# Session 431 processed successfully.
# Processing session 432
# Session 432 processed successfully.
# Processing session 433
# Session 433 processed successfully.
# Processing session 434
# Session 434 processed successfully.
# Processing session 435
# Session 435 processed successfully.
# Processing session 436
# Session 436 processed successfully.
# Processing session 437
# Session 437 processed successfully.
# Processing session 438
# Session 438 processed successfully.
# Processing session 439
# Session 439 processed successfully.
# Processing session 440
# Session 440 processed successfully.
# Processing session 441
# Session 441 processed successfully.
# Processing session 442
# Session 442 processed successfully.
# Processing session 443
# Session 443 processed successfully.
# Processing session 444
# Session 444 processed successfully.
# Processing session 445
# Session 445 processed successfully.
# Processing session 446
# Session 446 processed successfully.
# Processing session 447
# Session 447 processed successfully.
# Processing session 448
# Session 448 processed successfully.
# Processing session 449
# Session 449 processed successfully.
# Processing session 450
# Session 450 processed successfully.
# Processing session 451
# Session 451 processed successfully.
# Processing session 452
# Session 452 processed successfully.
# Processing session 453
# Session 453 processed successfully.
# Processing session 454
# Session 454 processed successfully.
# Processing session 455
# Session 455 processed successfully.
# Processing session 456
# Session 456 processed successfully.
# Processing session 457
# Session 457 processed successfully.
# Processing session 458
# Session 458 processed successfully.
# Processing session 459
# Session 459 processed successfully.
# Processing session 460
# Session 460 processed successfully.
# Processing session 461
# Session 461 processed successfully.
# Processing session 462
# Session 462 processed successfully.
# Processing session 463
# Session 463 processed successfully.
# Processing session 464
# Session 464 processed successfully.
# Processing session 465
# Session 465 processed successfully.
# Processing session 466
# Session 466 processed successfully.
# Processing session 467
# Session 467 processed successfully.
# Processing session 468
# Session 468 processed successfully.
# Processing session 469
# Session 469 processed successfully.
# Processing session 470
# Session 470 processed successfully.
# Processing session 471
# Session 471 processed successfully.
# Processing session 472
# Session 472 processed successfully.
# Processing session 473
# Session 473 processed successfully.
# Processing session 474
# Session 474 processed successfully.
# Processing session 475
# Session 475 processed successfully.
# Processing session 476
# Session 476 processed successfully.
# Processing session 477
# Session 477 processed successfully.
# Processing session 478
# Session 478 processed successfully.
# Processing session 479
# Session 479 processed successfully.
# Processing session 480
# Session 480 processed successfully.
# Processing session 481
# Session 481 processed successfully.
# Processing session 482
# Session 482 processed successfully.
# Processing session 483
# Session 483 processed successfully.
# Processing session 484
# Session 484 processed successfully.
# Processing session 485
# Session 485 processed successfully.
# Processing session 486
# Session 486 processed successfully.
# Processing session 487
# Session 487 processed successfully.
# Processing session 488
# Session 488 processed successfully.
# Processing session 489
# Session 489 processed successfully.
# Processing session 490
# Session 490 processed successfully.
# Processing session 491
# Session 491 processed successfully.
# Processing session 492
# Session 492 processed successfully.
# Processing session 493
# Session 493 processed successfully.
# Processing session 494
# Session 494 processed successfully.
# Processing session 495
# Session 495 processed successfully.
# Processing session 496
# Session 496 processed successfully.
# Processing session 497
# Session 497 processed successfully.
# Processing session 498
# Session 498 processed successfully.
# Processing session 499
# Session 499 processed successfully.
# Processing session 500
# Session 500 processed successfully.
# Processing session 501
# Session 501 processed successfully.
# Processing session 502
# Session 502 processed successfully.
# Processing session 503
# Session 503 processed successfully.
# Processing session 504
# Session 504 processed successfully.
# Processing session 505
# Session 505 processed successfully.
# Processing session 506
# Session 506 processed successfully.
# Processing session 507
# Session 507 processed successfully.
# Processing session 508
# Session 508 processed successfully.
# Processing session 509
# Session 509 processed successfully.
# Processing session 510
# Session 510 processed successfully.
# Processing session 511
# Session 511 processed successfully.
# Processing session 512
# Session 512 processed successfully.
# Processing session 513
# Session 513 processed successfully.
# Processing session 514
# Session 514 processed successfully.
# Processing session 515
# Session 515 processed successfully.
# Processing session 516
# Session 516 processed successfully.
# Processing session 517
# Session 517 processed successfully.
# Processing session 518
# Session 518 processed successfully.
# Processing session 519
# Session 519 processed successfully.
# Processing session 520
# Session 520 processed successfully.
# Processing session 521
# Session 521 processed successfully.
# Processing session 522
# Session 522 processed successfully.
# Processing session 523
# Session 523 processed successfully.
# Processing session 524
# Session 524 processed successfully.
# Processing session 525
# Session 525 processed successfully.
# Processing session 526
# Session 526 processed successfully.
# Processing session 527
# Session 527 processed successfully.
# Processing session 528
# Session 528 processed successfully.
# Processing session 529
# Session 529 processed successfully.
# Processing session 530
# Session 530 processed successfully.
# Processing session 531
# Session 531 processed successfully.
# Processing session 532
# Session 532 processed successfully.
# Processing session 533
# Session 533 processed successfully.
# Processing session 534
# Session 534 processed successfully.
# Processing session 535
# Session 535 processed successfully.
# Processing session 536
# Session 536 processed successfully.
# Processing session 537
# Session 537 processed successfully.
# Processing session 538
# Session 538 processed successfully.
# Processing session 539
# Session 539 processed successfully.
# Processing session 540
# Session 540 processed successfully.
# Processing session 541
# Session 541 processed successfully.
# Processing session 542
# Session 542 processed successfully.
# Processing session 543
# Session 543 processed successfully.
# Processing session 544
# Session 544 processed successfully.
# Processing session 545
# Session 545 processed successfully.
# Processing session 546
# Session 546 processed successfully.
# Processing session 547
# Session 547 processed successfully.
# Processing session 548
# Session 548 processed successfully.
# Processing session 549
# Session 549 processed successfully.
# Processing session 550
# Session 550 processed successfully.
# Processing session 551
# Session 551 processed successfully.
# Processing session 552
# Session 552 processed successfully.
# Processing session 553
# Session 553 processed successfully.
# Processing session 554
# Session 554 processed successfully.
# Processing session 555
# Session 555 processed successfully.
# Processing session 556
# Session 556 processed successfully.
# Processing session 557
# Session 557 processed successfully.
# Processing session 558
# Session 558 processed successfully.
# Processing session 559
# Session 559 processed successfully.
# Processing session 560
# Session 560 processed successfully.
# Processing session 561
# Session 561 processed successfully.
# Processing session 562
# Session 562 processed successfully.
# Processing session 563
# Session 563 processed successfully.
# Processing session 564
# Session 564 processed successfully.
# Processing session 565
# Session 565 processed successfully.
# Processing session 566
# Session 566 processed successfully.
# Processing session 567
# Session 567 processed successfully.
# Processing session 568
# Session 568 processed successfully.
# Processing session 569
# Session 569 processed successfully.
# Processing session 570
# Session 570 processed successfully.
# Processing session 571
# Session 571 processed successfully.
# Processing session 572
# Session 572 processed successfully.
# Processing session 573
# Session 573 processed successfully.
# Processing session 574
# Session 574 processed successfully.
# Processing session 575
# Session 575 processed successfully.
# Processing session 576
# Session 576 processed successfully.
# Processing session 577
# Session 577 processed successfully.
# Processing session 578
# Session 578 processed successfully.
# Processing session 579
# Session 579 processed successfully.
# Processing session 580
# Session 580 processed successfully.
# Processing session 581
# Session 581 processed successfully.
# Processing session 582
# Session 582 processed successfully.
# Processing session 583
# Session 583 processed successfully.
# Processing session 584
# Session 584 processed successfully.
# Processing session 585
# Session 585 processed successfully.
# Processing session 586
# Session 586 processed successfully.
# Processing session 587
# Session 587 processed successfully.
# Processing session 588
# Session 588 processed successfully.
# Processing session 589
# Session 589 processed successfully.
# Processing session 590
# Session 590 processed successfully.
# Processing session 591
# Session 591 processed successfully.
# Processing session 592
# Session 592 processed successfully.
# Processing session 593
# Session 593 processed successfully.
# Processing session 594
# Session 594 processed successfully.
# Processing session 595
# Session 595 processed successfully.
# Processing session 596
# Session 596 processed successfully.
# Processing session 597
# Session 597 processed successfully.
# Processing session 598
# Session 598 processed successfully.
# Processing session 599
# Session 599 processed successfully.
# Processing session 600
# Session 600 processed successfully.
# Processing session 601
# Session 601 processed successfully.
# Processing session 602
# Session 602 processed successfully.
# Processing session 603
# Session 603 processed successfully.
# Processing session 604
# Session 604 processed successfully.
# Processing session 605
# Session 605 processed successfully.
# Processing session 606
# Session 606 processed successfully.
# Processing session 607
# Session 607 processed successfully.
# Processing session 608
# Session 608 processed successfully.
# Processing session 609
# Session 609 processed successfully.
# Processing session 610
# Session 610 processed successfully.
# Processing session 611
# Session 611 processed successfully.
# Processing session 612
# Session 612 processed successfully.
# Processing session 613
# Session 613 processed successfully.
# Processing session 614
# Session 614 processed successfully.
# Processing session 615
# Session 615 processed successfully.
# Processing session 616
# Session 616 processed successfully.
# Processing session 617
# Session 617 processed successfully.
# Processing session 618
# Session 618 processed successfully.
# Processing session 619
# Session 619 processed successfully.
# Processing session 620
# Session 620 processed successfully.
# Processing session 621
# Session 621 processed successfully.
# Processing session 622
# Session 622 processed successfully.
# Processing session 623
# Session 623 processed successfully.
# Processing session 624
# Session 624 processed successfully.
# Processing session 625
# Session 625 processed successfully.
# Processing session 626
# Session 626 processed successfully.
# Processing session 627
# Session 627 processed successfully.
# Processing session 628
# Session 628 processed successfully.
# Processing session 629
# Session 629 processed successfully.
# Processing session 630
# Session 630 processed successfully.
# Processing session 631
# Session 631 processed successfully.
# Processing session 632
# Session 632 processed successfully.
# Processing session 633
# Session 633 processed successfully.
# Processing session 634
# Session 634 processed successfully.
# Processing session 635
# Session 635 processed successfully.
# Processing session 636
# Session 636 processed successfully.
# Processing session 637
# Session 637 processed successfully.
# Processing session 638
# Session 638 processed successfully.
# Processing session 639
# Session 639 processed successfully.
# Processing session 640
# Session 640 processed successfully.
# Processing session 641
# Session 641 processed successfully.
# Processing session 642
# Session 642 processed successfully.
# Processing session 643
# Session 643 processed successfully.
# Processing session 644
# Session 644 processed successfully.
# Processing session 645
# Session 645 processed successfully.
# Processing session 646
# Session 646 processed successfully.
# Processing session 647
# Session 647 processed successfully.
# Processing session 648
# Session 648 processed successfully.
# Processing session 649
# Session 649 processed successfully.
# Processing session 650
# Session 650 processed successfully.
# Processing session 651
# Session 651 processed successfully.
# Processing session 652
# Session 652 processed successfully.
# Processing session 653
# Session 653 processed successfully.
# Processing session 654
# Session 654 processed successfully.
# Processing session 655
# Session 655 processed successfully.
# Processing session 656
# Session 656 processed successfully.
# Processing session 657
# Session 657 processed successfully.
# Processing session 658
# Session 658 processed successfully.
# Processing session 659
# Session 659 processed successfully.
# Processing session 660
# Session 660 processed successfully.
# Processing session 661
# Session 661 processed successfully.
# Processing session 662
# Session 662 processed successfully.
# Processing session 663
# Session 663 processed successfully.
# Processing session 664
# Session 664 processed successfully.
# Processing session 665
# Session 665 processed successfully.
# Processing session 666
# Session 666 processed successfully.
# Processing session 667
# Session 667 processed successfully.
# Processing session 668
# Session 668 processed successfully.
# Processing session 669
# Session 669 processed successfully.
# Processing session 670
# Session 670 processed successfully.
# Processing session 671
# Session 671 processed successfully.
# Processing session 672
# Session 672 processed successfully.
# Processing session 673
# Session 673 processed successfully.
# Processing date directory: /Volumes/One Touch/data/ipad_augusto|mac_luca/2024-11-20
# Processing session 001
# Session 001 processed successfully.
# Processing session 002
# Session 002 processed successfully.
# Processing session 003
# Session 003 processed successfully.
# Processing session 004
# Session 004 processed successfully.
# Processing session 005
# Session 005 processed successfully.
# Processing session 006
# Session 006 processed successfully.
# Processing session 007
# Session 007 processed successfully.
# Processing session 008
# Session 008 processed successfully.
# Processing session 009
# Session 009 processed successfully.
# Processing session 010
# Session 010 processed successfully.
# Processing session 011
# Session 011 processed successfully.
# Processing session 012
# Session 012 processed successfully.
# Processing session 013
# Session 013 processed successfully.
# Processing session 014
# Session 014 processed successfully.
# Processing session 015
# Session 015 processed successfully.
# Processing session 016
# Session 016 processed successfully.
# Processing session 017
# Session 017 processed successfully.
# Processing session 018
# Session 018 processed successfully.
# Processing session 019
# Session 019 processed successfully.
# Processing session 020
# Session 020 processed successfully.
# Processing session 021
# Session 021 processed successfully.
# Processing session 022
# Session 022 processed successfully.
# Processing session 023
# Session 023 processed successfully.
# Processing session 024
# Session 024 processed successfully.
# Processing session 025
# Session 025 processed successfully.
# Processing session 026
# Session 026 processed successfully.
# Processing session 027
# Session 027 processed successfully.
# Processing session 028
# Session 028 processed successfully.
# Processing session 029
# Session 029 processed successfully.
# Processing session 030
# Session 030 processed successfully.
# Processing session 031
# Session 031 processed successfully.
# Processing session 032
# Session 032 processed successfully.
# Processing session 033
# Session 033 processed successfully.
# Processing session 034
# Session 034 processed successfully.
# Processing session 035
# Session 035 processed successfully.
# Processing session 036
# Session 036 processed successfully.
# Processing session 037
# Session 037 processed successfully.
# Processing session 038
# Session 038 processed successfully.
# Processing session 039
# Session 039 processed successfully.
# Processing session 040
# Session 040 processed successfully.
# Processing session 041
# Session 041 processed successfully.
# Processing session 042
# Session 042 processed successfully.
# Processing session 043
# Session 043 processed successfully.
# Processing session 044
# Session 044 processed successfully.
# Processing session 045
# Session 045 processed successfully.
# Processing session 046
# Session 046 processed successfully.
# Processing session 047
# Session 047 processed successfully.
# Processing session 048
# Session 048 processed successfully.
# Processing session 049
# Session 049 processed successfully.
# Processing session 050
# Session 050 processed successfully.
# Processing session 051
# Session 051 processed successfully.
# Processing session 052
# Session 052 processed successfully.
# Processing session 053
# Session 053 processed successfully.
# Processing session 054
# Session 054 processed successfully.
# Processing session 055
# Session 055 processed successfully.
# Processing session 056
# Session 056 processed successfully.
# Processing session 057
# Session 057 processed successfully.
# Processing session 058
# Session 058 processed successfully.
# Processing session 059
# Session 059 processed successfully.
# Processing session 060
# Session 060 processed successfully.
# Processing session 061
# Session 061 processed successfully.
# Processing session 062
# Session 062 processed successfully.
# Processing session 063
# Session 063 processed successfully.
# Processing session 064
# Session 064 processed successfully.
# Processing session 065
# Session 065 processed successfully.
# Processing session 066
# Session 066 processed successfully.
# Processing session 067
# Session 067 processed successfully.
# Processing session 068
# Session 068 processed successfully.
# Processing session 069
# Session 069 processed successfully.
# Processing session 070
# Session 070 processed successfully.
# Processing session 071
# Session 071 processed successfully.
# Processing session 072
# Session 072 processed successfully.
# Processing session 073
# Session 073 processed successfully.
# Processing session 074
# Session 074 processed successfully.
# Processing session 075
# Session 075 processed successfully.
# Processing session 076
# Session 076 processed successfully.
# Processing session 077
# Session 077 processed successfully.
# Processing session 078
# Session 078 processed successfully.
# Processing session 079
# Session 079 processed successfully.
# Processing session 080
# Session 080 processed successfully.
# Processing session 081
# Session 081 processed successfully.
# Processing session 082
# Session 082 processed successfully.
# Processing session 083
# Session 083 processed successfully.
# Processing session 084
# Session 084 processed successfully.
# Processing session 085
# Session 085 processed successfully.
# Processing session 086
# Session 086 processed successfully.
# Processing session 087
# Session 087 processed successfully.
# Processing session 088
# Session 088 processed successfully.
# Processing session 089
# Session 089 processed successfully.
# Processing session 090
# Session 090 processed successfully.
# Processing session 091
# Session 091 processed successfully.
# Processing session 092
# Session 092 processed successfully.
# Processing session 093
# Session 093 processed successfully.
# Processing session 094
# Session 094 processed successfully.
# Processing session 095
# Session 095 processed successfully.
# Processing session 096
# Session 096 processed successfully.
# Processing session 097
# Session 097 processed successfully.
# Processing session 098
# Session 098 processed successfully.
# Processing session 099
# Session 099 processed successfully.
# Processing session 100
# Session 100 processed successfully.
# Processing session 101
# Session 101 processed successfully.
# Processing session 102
# Session 102 processed successfully.
# Processing session 103
# Session 103 processed successfully.
# Processing session 104
# Session 104 processed successfully.
# Processing session 105
# Session 105 processed successfully.
# Processing session 106
# Session 106 processed successfully.
# Processing session 107
# Session 107 processed successfully.
# Processing session 108
# Session 108 processed successfully.
# Processing session 109
# Session 109 processed successfully.
# Processing session 110
# Session 110 processed successfully.
# Processing session 111
# Session 111 processed successfully.
# Processing session 112
# Session 112 processed successfully.
# Processing session 113
# Session 113 processed successfully.
# Processing session 114
# Session 114 processed successfully.
# Processing session 115
# Session 115 processed successfully.
# Processing session 116
# Session 116 processed successfully.
# Processing session 117
# Session 117 processed successfully.
# Processing session 118
# Session 118 processed successfully.
# Processing session 119
# Session 119 processed successfully.
# Processing session 120
# Session 120 processed successfully.
# Processing session 121
# Session 121 processed successfully.
# Processing session 122
# Session 122 processed successfully.
# Processing session 123
# Session 123 processed successfully.
# Processing session 124
# Session 124 processed successfully.
# Processing session 125
# Session 125 processed successfully.
# Processing session 126
# Session 126 processed successfully.
# Processing session 127
# Session 127 processed successfully.
# Processing session 128
# Session 128 processed successfully.
# Processing session 129
# Session 129 processed successfully.
# Processing session 130
# Session 130 processed successfully.
# Processing session 131
# Session 131 processed successfully.
# Processing session 132
# Session 132 processed successfully.
# Processing session 133
# Session 133 processed successfully.
# Processing session 134
# Session 134 processed successfully.
# Processing session 135
# Session 135 processed successfully.
# Processing session 136
# Session 136 processed successfully.
# Processing session 137
# Session 137 processed successfully.
# Processing session 138
# ...
# Processing session 249
# Session 249 processed successfully.
# Processing session 250
# Session 250 processed successfully.
# Processing session 251
# Session 251 processed successfully.
# Processing session 252
# Session 252 processed successfully.
# Processing session 253
# Session 253 processed successfully.
# Processing session 254
# Session 254 processed successfully.
# Processing session 255
# Session 255 processed successfully.
# Processing session 256
# Session 256 processed successfully.
# Processing session 257
# Session 257 processed successfully.
# Processing session 258
# Session 258 processed successfully.
# Processing session 259
# Session 259 processed successfully.
# Processing session 260
# Session 260 processed successfully.
# Processing session 261
# Session 261 processed successfully.
# Processing session 262
# Session 262 processed successfully.
# Processing session 263
# Session 263 processed successfully.
# Processing session 264
# Session 264 processed successfully.
# Processing session 265
# Session 265 processed successfully.
# Processing session 266
# Session 266 processed successfully.
# Processing session 267
# Session 267 processed successfully.
# Processing session 268
# Session 268 processed successfully.
# Processing session 269
# Session 269 processed successfully.
# Processing session 270
# Session 270 processed successfully.
# Processing session 271
# Session 271 processed successfully.
# Processing session 272
# Session 272 processed successfully.
# Processing session 273
# Session 273 processed successfully.
# Processing session 274
# Session 274 processed successfully.
# Processing session 275
# Session 275 processed successfully.
# Processing session 276
# Session 276 processed successfully.
# Processing session 277
# Session 277 processed successfully.
# Processing session 278
# Session 278 processed successfully.
# Processing session 279
# Session 279 processed successfully.
# Processing session 280
# Session 280 processed successfully.
# Processing session 281
# Session 281 processed successfully.
# Processing session 282
# Session 282 processed successfully.
# Processing session 283
# Session 283 processed successfully.
# Processing session 284
# Session 284 processed successfully.
# Processing session 285
# Session 285 processed successfully.
# Processing session 286
# Session 286 processed successfully.
# Processing session 287
# Session 287 processed successfully.
# Processing session 288
# Session 288 processed successfully.
# Processing session 289
# Session 289 processed successfully.
# Processing session 290
# Session 290 processed successfully.
# Processing session 291
# Session 291 processed successfully.
# Processing session 292
# Session 292 processed successfully.
# Processing session 293
# Session 293 processed successfully.
# Processing session 294
# Session 294 processed successfully.
# Processing session 295
# Session 295 processed successfully.
# Processing session 296
# Session 296 processed successfully.
# Processing session 297
# Session 297 processed successfully.
# Processing session 298
# Session 298 processed successfully.
# Processing session 299
# Session 299 processed successfully.
# Processing session 300
# Session 300 processed successfully.
# Processing session 301
# Session 301 processed successfully.
# Processing session 302
# Session 302 processed successfully.
# Processing session 303
# Session 303 processed successfully.
# Processing session 304
# Session 304 processed successfully.
# Processing session 305
# Session 305 processed successfully.
# Processing session 306
# Session 306 processed successfully.
# Processing session 307
# Session 307 processed successfully.
# Processing session 308
# Session 308 processed successfully.
# Processing session 309
# Session 309 processed successfully.
# Processing session 310
# Session 310 processed successfully.
# Processing session 311
# Session 311 processed successfully.
# Processing session 312
# Session 312 processed successfully.
# Processing session 313
# Session 313 processed successfully.
# Processing session 314
# Session 314 processed successfully.
# Processing session 315
# Session 315 processed successfully.
# Processing session 316
# Session 316 processed successfully.
# Processing session 317
# Session 317 processed successfully.
# Processing session 318
# Session 318 processed successfully.
# Processing session 319
# Session 319 processed successfully.
# Processing session 320
# Session 320 processed successfully.
# Processing session 321
# Session 321 processed successfully.
# Processing session 322
# Session 322 processed successfully.
# Processing session 323
# Session 323 processed successfully.
# Processing session 324
# Session 324 processed successfully.
# Processing session 325
# Session 325 processed successfully.
# Processing session 326
# Session 326 processed successfully.
# Processing session 327
# Session 327 processed successfully.
# Processing session 328
# Session 328 processed successfully.
# Processing session 329
# Session 329 processed successfully.
# Processing session 330
# Session 330 processed successfully.
# Processing session 331
# Session 331 processed successfully.
# Processing session 332
# Session 332 processed successfully.
# Processing session 333
# Session 333 processed successfully.
# Processing session 334
# Session 334 processed successfully.
# Processing session 335
# Session 335 processed successfully.
# Processing session 336
# Session 336 processed successfully.
# Processing session 337
# Session 337 processed successfully.
# Processing session 338
# Session 338 processed successfully.
# Processing session 339
# Session 339 processed successfully.
# Processing session 340
# Session 340 processed successfully.
# Processing session 341
# Session 341 processed successfully.
# Processing session 342
# Session 342 processed successfully.
# Processing session 343
# Session 343 processed successfully.
# Processing session 344
# Session 344 processed successfully.
# Processing session 345
# Session 345 processed successfully.
# Processing session 346
# Session 346 processed successfully.
# Processing session 347
# Session 347 processed successfully.
# Processing session 348
# Session 348 processed successfully.
# Processing session 349
# Session 349 processed successfully.
# Processing session 350
# Session 350 processed successfully.
# Processing session 351
# Session 351 processed successfully.
# Processing session 352
# Session 352 processed successfully.
# Processing session 353
# Session 353 processed successfully.
# Processing session 354
# Session 354 processed successfully.
# Processing session 355
# Session 355 processed successfully.
# Processing session 356
# Session 356 processed successfully.
# Processing session 357
# Session 357 processed successfully.
# Processing session 358
# Session 358 processed successfully.
# Processing session 359
# Session 359 processed successfully.
# Processing session 360
# Session 360 processed successfully.
# Processing session 361
# Session 361 processed successfully.
# Processing session 362
# Session 362 processed successfully.
# Processing session 363
# Session 363 processed successfully.
# Processing session 364
# Session 364 processed successfully.
# Processing session 365
# Session 365 processed successfully.
# Processing session 366
# Session 366 processed successfully.
# Processing session 367
# Session 367 processed successfully.
# Processing session 368
# Session 368 processed successfully.
# Processing session 369
# Session 369 processed successfully.
# Processing session 370
# Session 370 processed successfully.
# Processing session 371
# Session 371 processed successfully.
# Processing session 372
# Session 372 processed successfully.
# Processing session 373
# Session 373 processed successfully.
# Processing session 374
# Session 374 processed successfully.
# Processing session 375
# Session 375 processed successfully.
# Processing session 376
# Session 376 processed successfully.
# Processing session 377
# Session 377 processed successfully.
# Processing session 378
# Session 378 processed successfully.
# Processing session 379
# Session 379 processed successfully.
# Processing session 380
# Session 380 processed successfully.
# Processing session 381
# Session 381 processed successfully.
# Processing session 382
# Session 382 processed successfully.
# Processing session 383
# Session 383 processed successfully.
# Processing session 384
# Session 384 processed successfully.
# Processing session 385
# Session 385 processed successfully.
# Processing session 386
# Session 386 processed successfully.
# Processing session 387
# Session 387 processed successfully.
# Processing session 388
# Session 388 processed successfully.
# Processing session 389
# Session 389 processed successfully.
# Processing session 390
# Session 390 processed successfully.
# Processing session 391
# Session 391 processed successfully.
# Processing session 392
# Session 392 processed successfully.
# Processing session 393
# Session 393 processed successfully.
# Processing session 394
# Session 394 processed successfully.
# Processing session 395
# Session 395 processed successfully.
# Processing session 396
# Session 396 processed successfully.
# Processing session 397
# Session 397 processed successfully.
# Processing session 398
# Session 398 processed successfully.
# Processing session 399
# Session 399 processed successfully.
# Processing session 400
# Session 400 processed successfully.
# Processing session 401
# Session 401 processed successfully.
# Processing session 402
# Session 402 processed successfully.
# Processing session 403
# Session 403 processed successfully.
# Processing session 404
# Session 404 processed successfully.
# Processing session 405
# Session 405 processed successfully.
# Processing session 406
# Session 406 processed successfully.
# Processing session 407
# Session 407 processed successfully.
# Processing session 408
# Session 408 processed successfully.
# Processing session 409
# Session 409 processed successfully.
# Processing session 410
# Session 410 processed successfully.
# Processing session 411
# Session 411 processed successfully.
# Processing session 412
# Session 412 processed successfully.
# Processing session 413
# Session 413 processed successfully.
# Processing session 414
# Session 414 processed successfully.
# Processing session 415
# Session 415 processed successfully.
# Processing session 416
# Session 416 processed successfully.
# Processing session 417
# Session 417 processed successfully.
# Processing session 418
# Session 418 processed successfully.
# Processing session 419
# Session 419 processed successfully.
# Processing session 420
# Session 420 processed successfully.
# Processing session 421
# Session 421 processed successfully.
# Processing session 422
# Session 422 processed successfully.
# Processing session 423
# Session 423 processed successfully.
# Processing session 424
# Session 424 processed successfully.
# Processing session 425
# Session 425 processed successfully.
# Processing session 426
# Session 426 processed successfully.
# Processing session 427
# Session 427 processed successfully.
# Processing session 428
# Session 428 processed successfully.
# Processing session 429
# Session 429 processed successfully.
# Processing session 430
# Session 430 processed successfully.
# Processing session 431
# Session 431 processed successfully.
# Processing session 432
# Session 432 processed successfully.
# Processing session 433
# Session 433 processed successfully.
# Processing session 434
# Session 434 processed successfully.
# Processing session 435
# Session 435 processed successfully.
# Processing session 436
# Session 436 processed successfully.
# Processing session 437
# Session 437 processed successfully.
# Processing session 438
# Session 438 processed successfully.
# Processing session 439
# Session 439 processed successfully.
# Processing session 440
# Session 440 processed successfully.
# Processing session 441
# Session 441 processed successfully.
# Processing session 442
# Session 442 processed successfully.
# Processing session 443
# Session 443 processed successfully.
# Processing session 444
# Session 444 processed successfully.
# Processing session 445
# Session 445 processed successfully.
# Processing session 446
# Session 446 processed successfully.
# Processing session 447
# Session 447 processed successfully.
# Processing session 448
# Session 448 processed successfully.
# Processing session 449
# Session 449 processed successfully.
# Processing session 450
# Session 450 processed successfully.
# Processing session 451
# Session 451 processed successfully.
# Processing session 452
# Session 452 processed successfully.
# Processing session 453
# Session 453 processed successfully.
# Processing session 454
# Session 454 processed successfully.
# Processing session 455
# Session 455 processed successfully.
# Processing session 456
# Session 456 processed successfully.
# Processing session 457
# Session 457 processed successfully.
# Processing session 458
# Session 458 processed successfully.
# Processing session 459
# Session 459 processed successfully.
# Processing session 460
# Session 460 processed successfully.
# Processing session 461
# Session 461 processed successfully.
# Processing session 462
# Session 462 processed successfully.
# Processing session 463
# Session 463 processed successfully.
# Processing session 464
# Session 464 processed successfully.
# Processing session 465
# Session 465 processed successfully.
# Processing session 466
# Session 466 processed successfully.
# Processing session 467
# Session 467 processed successfully.
# Processing session 468
# Session 468 processed successfully.
# Processing session 469
# Session 469 processed successfully.
# Processing session 470
# Session 470 processed successfully.
# Processing session 471
# Session 471 processed successfully.
# Processing session 472
# Session 472 processed successfully.
# Processing session 473
# Session 473 processed successfully.
# Processing session 474
# Session 474 processed successfully.
# Processing session 475
# Session 475 processed successfully.
# Processing session 476
# Session 476 processed successfully.
# Processing session 477
# Session 477 processed successfully.
# Processing session 478
# Session 478 processed successfully.
# Processing session 479
# Session 479 processed successfully.
# Processing session 480
# Session 480 processed successfully.
# Processing session 481
# Session 481 processed successfully.
# Processing session 482
# Session 482 processed successfully.
# Processing session 483
# Session 483 processed successfully.
# Processing session 484
# Session 484 processed successfully.
# Processing session 485
# Session 485 processed successfully.
# Processing session 486
# Session 486 processed successfully.
# Processing session 487
# Session 487 processed successfully.
# Processing session 488
# Session 488 processed successfully.
# Processing session 489
# Session 489 processed successfully.
# Processing session 490
# Session 490 processed successfully.
# Processing session 491
# Session 491 processed successfully.
# Processing session 492
# Session 492 processed successfully.
# Processing session 493
# Session 493 processed successfully.
# Processing session 494
# Session 494 processed successfully.
# Processing session 495
# Session 495 processed successfully.
# Processing session 496
# Session 496 processed successfully.
# Processing session 497
# Session 497 processed successfully.
# Processing session 498
# Session 498 processed successfully.
# Processing session 499
# Session 499 processed successfully.
# Processing session 500
# Session 500 processed successfully.
# Processing session 501
# Session 501 processed successfully.
# Processing session 502
# Session 502 processed successfully.
# Processing session 503
# Session 503 processed successfully.
# Processing session 504
# Session 504 processed successfully.
# Processing session 505
# Session 505 processed successfully.
# Processing session 506
# Session 506 processed successfully.
# Processing session 507
# Session 507 processed successfully.
# Processing session 508
# Session 508 processed successfully.
# Processing session 509
# Session 509 processed successfully.
# Processing session 510
# Session 510 processed successfully.
# Processing session 511
# Session 511 processed successfully.
# Processing session 512
# Session 512 processed successfully.
# Processing session 513
# Session 513 processed successfully.
# Processing session 514
# Session 514 processed successfully.
# Processing session 515
# Session 515 processed successfully.
# Processing session 516
# Session 516 processed successfully.
# Processing session 517
# Session 517 processed successfully.
# Summary CSV successfully saved to /Volumes/One Touch/data/ipad_augusto|mac_luca/summary_features_welch.csv

# %% [markdown]
# # all, signal processing type by type (fft, welch, histogram)

# %%
import os
import json
import pandas as pd
import numpy as np
import re
from scipy import stats
from scipy.signal import welch
from PyEMD import EMD
import matplotlib.pyplot as plt  # For histogram computation (optional)

# ---------------------------
# Configuration and Setup
# ---------------------------

def load_config(config_path='config.json'):
    """
    Load configuration parameters from a JSON file.
    """
    if not os.path.exists(config_path):
        raise FileNotFoundError(f"Configuration file '{config_path}' not found.")
    
    with open(config_path, 'r') as f:
        config = json.load(f)
    
    required_keys = ['base_dir']
    for key in required_keys:
        if key not in config:
            raise KeyError(f"Missing required configuration key: '{key}'")
    
    return config

# ---------------------------
# Statistical Feature Computation
# ---------------------------

def compute_statistical_features(data_array):
    """
    Compute statistical features from a data array (e.g., power spectrum or histogram).
    """
    features = {}
    try:
        features['entropy'] = stats.entropy(np.abs(data_array))
        features['skewness'] = stats.skew(data_array)
        features['interquartile_range'] = np.percentile(data_array, 75) - np.percentile(data_array, 25)
        features['kurtosis'] = stats.kurtosis(data_array)
        features['percentile_75'] = np.percentile(data_array, 75)
        features['range'] = np.ptp(data_array)
        features['maximum'] = np.max(data_array)
        features['median'] = np.median(data_array)
        features['percentile_90'] = np.percentile(data_array, 90)
        features['mean_absolute_deviation'] = np.mean(np.abs(data_array - np.mean(data_array)))
    except Exception as e:
        print(f"Error computing statistical features: {e}")
        features = {key: np.nan for key in ['entropy', 'skewness', 'interquartile_range', 'kurtosis',
                                            'percentile_75', 'range', 'maximum', 'median',
                                            'percentile_90', 'mean_absolute_deviation']}
    return features

# ---------------------------
# Channel Processing
# ---------------------------

def process_channel(df_channel, channel_label, decimation_factor, processing_method):
    """
    Process a single channel and return computed features.
    """
    try:
        if df_channel.empty or 'voltage' not in df_channel.columns:
            print(f"No data or missing 'voltage' column in {channel_label}")
            return None
        
        # Handle NaN values
        if df_channel['voltage'].isnull().any():
            print(f"NaN values found in {channel_label}. They will be ignored.")
            df_channel = df_channel.dropna(subset=['voltage'])
            if df_channel.empty:
                print(f"All data is NaN in {channel_label}. Skipping.")
                return None
        
        # Process the signal
        signal = df_channel['voltage'].values
        signal = signal - np.mean(signal)  # Remove DC component

        if processing_method.lower() == 'welch':
            frequencies, power_spectrum = welch(signal, fs=125e6 / decimation_factor, nperseg=1024)
            data_to_analyze = power_spectrum
        elif processing_method.lower() == 'fft':
            # Using FFT
            N = len(signal)
            frequencies = np.fft.fftfreq(N, d=1/(125e6 / decimation_factor))
            power_spectrum = np.abs(np.fft.fft(signal))**2 / N
            data_to_analyze = power_spectrum
        elif processing_method.lower() == 'bd':
            # Implement blind deconvolution using EMD
            emd = EMD()
            IMFs = emd.emd(signal)
            if IMFs.size == 0:
                print(f"No IMFs found for {channel_label}. Skipping.")
                return None
            # Reconstruct the signal (e.g., sum all IMFs)
            reconstructed_signal = np.sum(IMFs, axis=0)
            frequencies, power_spectrum = welch(reconstructed_signal, fs=125e6 / decimation_factor, nperseg=1024)
            data_to_analyze = power_spectrum
        elif processing_method.lower() == 'histogram':
            # Compute histogram of the time-domain voltage signal
            hist_counts, bin_edges = np.histogram(signal, bins=50, density=True)
            data_to_analyze = hist_counts  # Use histogram counts for feature computation
        else:
            raise ValueError(f"Invalid processing method: {processing_method}")
        
        # For methods other than 'histogram', process power spectrum
        if processing_method.lower() != 'histogram':
            # Avoid log of zero by replacing zeros with a very small number
            data_to_analyze = np.where(data_to_analyze == 0, 1e-12, data_to_analyze)
            power_dbm = 10 * np.log10(data_to_analyze / 50)  # Assuming 50 ohm impedance
            mask = (frequencies >= 10e3) & (frequencies <= 100e3)
            filtered_data = power_dbm[mask]
        else:
            # For 'histogram', use the histogram counts directly
            filtered_data = data_to_analyze  # Already processed
        
        # Compute statistical features
        features = compute_statistical_features(filtered_data)
        
        # Prefix feature names with channel label
        features = {f"{channel_label}_{key}": value for key, value in features.items()}
        
        return features
    
    except Exception as e:
        print(f"Error processing {channel_label}: {e}")
        return None

# ---------------------------
# Session Processing
# ---------------------------

def process_session(ch1_filepath, ch2_filepath, decimation_factor, processing_method):
    """
    Process a single session by computing features for CH1 and CH2 using the specified processing method.
    Returns a dictionary with all required information.
    """
    session_data = {}
    try:
        # Extract session number from filename
        session_match = re.search(r'session_(\d{3})_CH1\.csv', os.path.basename(ch1_filepath))
        if not session_match:
            print(f"Invalid CH1 filename format: {ch1_filepath}")
            return None
        session_number = int(session_match.group(1))
        session_data['session'] = session_number
        
        # Extract date from filepath
        # Assuming the path is base_dir/device_label/YYYY-MM-DD/session_###_CHx.csv
        date_str = os.path.basename(os.path.dirname(ch1_filepath))
        session_data['date'] = date_str
        
        # Read CH1 data
        df_ch1 = pd.read_csv(ch1_filepath)
        
        # Process CH1
        ch1_features = process_channel(df_ch1, 'ch1', decimation_factor, processing_method)
        if ch1_features is None:
            print(f"Failed to process CH1 for session {session_number}")
            return None
        
        # Get the first timestamp as session timestamp
        timestamp_str = df_ch1['timestamp'].iloc[0]
        session_data['timestamp'] = timestamp_str
        
        # Read CH2 data
        df_ch2 = pd.read_csv(ch2_filepath)
        
        # Process CH2
        ch2_features = process_channel(df_ch2, 'ch2', decimation_factor, processing_method)
        if ch2_features is None:
            print(f"Failed to process CH2 for session {session_number}")
            return None
        
        # Combine features
        session_data.update(ch1_features)
        session_data.update(ch2_features)
        
    except Exception as e:
        print(f"Error processing session {ch1_filepath} and {ch2_filepath}: {e}")
        return None
    
    return session_data

# ---------------------------
# Main Processing Function
# ---------------------------

def main():
    # Load configuration
    try:
        config = load_config('config.json')
    except (FileNotFoundError, KeyError, ValueError) as e:
        print(f"Configuration Error: {e}")
        return
    
    base_dir = config['base_dir']
    decimation_factor = config.get('decimation_factor', 1024)  # Default to 1024 if not specified
    # processing_methods = ['fft', 'welch', 'bd', 'histogram']  # List of processing methods
    processing_methods = ['histogram']

    # Get list of devices in base_dir
    device_labels = [d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))]

    for device_label in device_labels:
        device_dir_path = os.path.join(base_dir, device_label)
        print(f"\nProcessing device: {device_label}")
        
        for processing_method in processing_methods:
            print(f"\nUsing processing method: {processing_method.upper()}")
            # Initialize a list to collect session data
            summary_data = []

            # Iterate over date directories
            date_dirs = [d for d in os.listdir(device_dir_path) if os.path.isdir(os.path.join(device_dir_path, d))]
            for date_dir in sorted(date_dirs):
                date_dir_path = os.path.join(device_dir_path, date_dir)
                
                print(f"Processing date directory: {date_dir_path}")
                
                # Find all session_###_CH1.csv files
                session_pattern = re.compile(r'session_(\d{3})_CH1\.csv')
                for filename in sorted(os.listdir(date_dir_path)):
                    match = session_pattern.match(filename)
                    if match:
                        session_number = match.group(1)
                        ch1_filepath = os.path.join(date_dir_path, filename)
                        ch2_filename = f'session_{session_number}_CH2.csv'
                        ch2_filepath = os.path.join(date_dir_path, ch2_filename)
                        
                        # Check if CH2 file exists
                        if not os.path.exists(ch2_filepath):
                            print(f"Missing CH2 file for session {session_number} in {date_dir_path}")
                            continue
                        
                        print(f"Processing session {session_number}")
                        
                        # Process the session
                        session_data = process_session(ch1_filepath, ch2_filepath, decimation_factor, processing_method)
                        if session_data:
                            session_data['device_label'] = device_label
                            summary_data.append(session_data)
                            print(f"Session {session_number} processed successfully.")
                        else:
                            print(f"Failed to process session {session_number} in {date_dir_path}")

            if summary_data:
                # Convert the list of dictionaries to a DataFrame
                summary_df = pd.DataFrame(summary_data)
                
                # Define the output summary CSV path
                output_summary_path = os.path.join(base_dir, device_label, f'summary_features_{processing_method.lower()}.csv')
                
                # Save the summary DataFrame to CSV
                try:
                    summary_df.to_csv(output_summary_path, index=False)
                    print(f"Summary CSV successfully saved to {output_summary_path}")
                except Exception as e:
                    print(f"Failed to save summary CSV: {e}")
            else:
                print(f"No data processed for device '{device_label}' with method '{processing_method}'.")

# ---------------------------
# Entry Point
# ---------------------------

if __name__ == "__main__":
    main()
# Out:
# Processing device: empty
#
# Using processing method: HISTOGRAM
# Processing date directory: /Volumes/One Touch/data/empty/2024-11-18
# Processing session 001
# Session 001 processed successfully.
# Processing session 002
# Session 002 processed successfully.
# Processing session 003
# Session 003 processed successfully.
# Processing session 004
# Session 004 processed successfully.
# Processing session 005
# Session 005 processed successfully.
# Processing session 006
# Session 006 processed successfully.
# Processing session 007
# Session 007 processed successfully.
# Processing session 008
# Session 008 processed successfully.
# Processing session 009
# Session 009 processed successfully.
# Processing session 010
# Session 010 processed successfully.
# Processing session 011
# Session 011 processed successfully.
# Processing session 012
# Session 012 processed successfully.
# Processing session 013
# Session 013 processed successfully.
# Processing session 014
# Session 014 processed successfully.
# Processing session 015
# Session 015 processed successfully.
# Processing session 016
# Session 016 processed successfully.
# Processing session 017
# Session 017 processed successfully.
# Processing session 018
# Session 018 processed successfully.
# Processing session 019
# Session 019 processed successfully.
# Processing session 020
# Session 020 processed successfully.
# Processing session 021
# Session 021 processed successfully.
# Processing session 022
# Session 022 processed successfully.
# Processing session 023
# Session 023 processed successfully.
# Processing session 024
# Session 024 processed successfully.
# Processing session 025
# Session 025 processed successfully.
# Processing session 026
# Session 026 processed successfully.
# Processing session 027
# Session 027 processed successfully.
# Processing session 028
# Session 028 processed successfully.
# Processing session 029
# Session 029 processed successfully.
# Processing session 030
# Session 030 processed successfully.
# Processing session 031
# Session 031 processed successfully.
# Processing session 032
# Session 032 processed successfully.
# Processing session 033
# Session 033 processed successfully.
# Processing session 034
# Session 034 processed successfully.
# Processing session 035
# Session 035 processed successfully.
# Processing session 036
# Session 036 processed successfully.
# Processing session 037
# Session 037 processed successfully.
# Processing session 038
# Session 038 processed successfully.
# Processing session 039
# Session 039 processed successfully.
# Processing session 040
# Session 040 processed successfully.
# Processing session 041
# Session 041 processed successfully.
# Processing session 042
# Session 042 processed successfully.
# Processing session 043
# Session 043 processed successfully.
# Processing session 044
# Session 044 processed successfully.
# Processing session 045
# Session 045 processed successfully.
# Processing session 046
# Session 046 processed successfully.
# Processing session 047
# Session 047 processed successfully.
# Processing session 048
# Session 048 processed successfully.
# Processing session 049
# Session 049 processed successfully.
# Processing session 050
# Session 050 processed successfully.
# Processing session 051
# Session 051 processed successfully.
# Processing session 052
# Session 052 processed successfully.
# Processing session 053
# Session 053 processed successfully.
# Processing session 054
# Session 054 processed successfully.
# Processing session 055
# Session 055 processed successfully.
# Processing session 056
# Session 056 processed successfully.
# Processing session 057
# Session 057 processed successfully.
# Processing session 058
# Session 058 processed successfully.
# Processing session 059
# Session 059 processed successfully.
# Processing session 060
# Session 060 processed successfully.
# Processing session 061
# Session 061 processed successfully.
# Processing session 062
# Session 062 processed successfully.
# Processing session 063
# Session 063 processed successfully.
# Processing session 064
# Session 064 processed successfully.
# Processing session 065
# Session 065 processed successfully.
# Processing session 066
# Session 066 processed successfully.
# Processing session 067
# Session 067 processed successfully.
# Processing session 068
# Session 068 processed successfully.
# Processing session 069
# Session 069 processed successfully.
# Processing session 070
# Session 070 processed successfully.
# Processing session 071
# Session 071 processed successfully.
# Processing session 072
# Session 072 processed successfully.
# Processing session 073
# Session 073 processed successfully.
# Processing session 074
# Session 074 processed successfully.
# Processing session 075
# Session 075 processed successfully.
# Processing session 076
# Session 076 processed successfully.
# Processing session 077
# Session 077 processed successfully.
# Processing session 078
# Session 078 processed successfully.
# Processing session 079
# Session 079 processed successfully.
# Processing session 080
# Session 080 processed successfully.
# Processing session 081
# Session 081 processed successfully.
# Processing session 082
# Session 082 processed successfully.
# Processing session 083
# Session 083 processed successfully.
# Processing session 084
# Session 084 processed successfully.
# Processing session 085
# Session 085 processed successfully.
# Processing session 086
# Session 086 processed successfully.
# Processing session 087
# Session 087 processed successfully.
# Processing session 088
# Session 088 processed successfully.
# Processing session 089
# Session 089 processed successfully.
# Processing session 090
# Session 090 processed successfully.
# Processing session 091
# Session 091 processed successfully.
# Processing session 092
# Session 092 processed successfully.
# Processing session 093
# Session 093 processed successfully.
# Processing session 094
# Session 094 processed successfully.
# Processing session 095
# Session 095 processed successfully.
# Processing session 096
# Session 096 processed successfully.
# Processing session 097
# Session 097 processed successfully.
# Processing session 098
# Session 098 processed successfully.
# Processing session 099
# Session 099 processed successfully.
# Processing session 100
# Session 100 processed successfully.
# Processing session 101
# Session 101 processed successfully.
# Processing session 102
# Session 102 processed successfully.
# Processing session 103
# Session 103 processed successfully.
# Processing session 104
# Session 104 processed successfully.
# Processing session 105
# Session 105 processed successfully.
# Processing session 106
# Session 106 processed successfully.
# Processing session 107
# Session 107 processed successfully.
# Processing session 108
# Session 108 processed successfully.
# Processing session 109
# Session 109 processed successfully.
# Processing session 110
# Session 110 processed successfully.
# Processing session 111
# Session 111 processed successfully.
# Processing session 112
# Session 112 processed successfully.
# Processing session 113
# Session 113 processed successfully.
# Processing session 114
# Session 114 processed successfully.
# Processing session 115
# Session 115 processed successfully.
# Processing session 116
# Session 116 processed successfully.
# Processing session 117
# Session 117 processed successfully.
# Processing session 118
# Session 118 processed successfully.
# Processing session 119
# Session 119 processed successfully.
# Processing session 120
# Session 120 processed successfully.
# Processing session 121
# Session 121 processed successfully.
# Processing session 122
# Session 122 processed successfully.
# Processing session 123
# Session 123 processed successfully.
# Processing session 124
# Session 124 processed successfully.
# Processing session 125
# Session 125 processed successfully.
# Processing session 126
# Session 126 processed successfully.
# Processing session 127
# Session 127 processed successfully.
# Processing session 128
# Session 128 processed successfully.
# Processing session 129
# Session 129 processed successfully.
# Processing session 130
# Session 130 processed successfully.
# Processing session 131
# Session 131 processed successfully.
# Processing session 132
# Session 132 processed successfully.
# Processing session 133
# Session 133 processed successfully.
# Processing session 134
# Session 134 processed successfully.
# Processing session 135
# Session 135 processed successfully.
# Processing session 136
# Session 136 processed successfully.
# Processing session 137
# Session 137 processed successfully.
# Processing session 138
# Session 138 processed successfully.
# Processing session 139
# Session 139 processed successfully.
# Processing session 140
# Session 140 processed successfully.
# Processing session 141
# Session 141 processed successfully.
# Processing session 142
# Session 142 processed successfully.
# Processing session 143
# Session 143 processed successfully.
# Processing session 144
# Session 144 processed successfully.
# Processing session 145
# Session 145 processed successfully.
# Processing session 146
# Session 146 processed successfully.
# Processing session 147
# Session 147 processed successfully.
# Processing session 148
# Session 148 processed successfully.
# Processing session 149
# Session 149 processed successfully.
# Processing session 150
# Session 150 processed successfully.
# Processing session 151
# Session 151 processed successfully.
# Processing session 152
# Session 152 processed successfully.
# Processing session 153
# Session 153 processed successfully.
# Processing session 154
# Session 154 processed successfully.
# Processing session 155
# Session 155 processed successfully.
# Processing session 156
# Session 156 processed successfully.
# Processing session 157
# Session 157 processed successfully.
# Processing session 158
# Session 158 processed successfully.
# Processing session 159
# Session 159 processed successfully.
# Processing session 160
# Session 160 processed successfully.
# Processing session 161
# Session 161 processed successfully.
# Processing session 162
# Session 162 processed successfully.
# Processing session 163
# Session 163 processed successfully.
# Processing session 164
# Session 164 processed successfully.
# Processing session 165
# Session 165 processed successfully.
# Processing session 166
# Session 166 processed successfully.
# Processing session 167
# Session 167 processed successfully.
# Processing session 168
# Session 168 processed successfully.
# Processing session 169
# Session 169 processed successfully.
# Processing session 170
# Session 170 processed successfully.
# Processing session 171
# Session 171 processed successfully.
# Processing session 172
# Session 172 processed successfully.
# Processing session 173
# Session 173 processed successfully.
# Processing session 174
# Session 174 processed successfully.
# Processing session 175
# Session 175 processed successfully.
# Processing session 176
# Session 176 processed successfully.
# Processing session 177
# Session 177 processed successfully.
# Processing session 178
# Session 178 processed successfully.
# Processing session 179
# Session 179 processed successfully.
# Processing session 180
# Session 180 processed successfully.
# Processing session 181
# Session 181 processed successfully.
# Processing session 182
# Session 182 processed successfully.
# Processing session 183
# Session 183 processed successfully.
# Processing session 184
# Session 184 processed successfully.
# Processing session 185
# Session 185 processed successfully.
# Processing session 186
# Session 186 processed successfully.
# Processing session 187
# Session 187 processed successfully.
# Processing session 188
# Session 188 processed successfully.
# Processing session 189
# Session 189 processed successfully.
# Processing session 190
# Session 190 processed successfully.
# Processing session 191
# Session 191 processed successfully.
# Processing session 192
# Session 192 processed successfully.
# Processing session 193
# Session 193 processed successfully.
# Processing session 194
# Session 194 processed successfully.
# Processing session 195
# Session 195 processed successfully.
# Processing session 196
# Session 196 processed successfully.
# Processing session 197
# Session 197 processed successfully.
# Processing session 198
# Session 198 processed successfully.
# Processing session 199
# Session 199 processed successfully.
# Processing session 200
# Session 200 processed successfully.
# Processing session 201
# Session 201 processed successfully.
# Processing session 202
# Session 202 processed successfully.
# Processing session 203
# Session 203 processed successfully.
# Processing session 204
# Session 204 processed successfully.
# Processing session 205
# Session 205 processed successfully.
# Processing session 206
# Session 206 processed successfully.
# Processing session 207
# Session 207 processed successfully.
# Processing session 208
# Session 208 processed successfully.
# Processing session 209
# Session 209 processed successfully.
# Processing session 210
# Session 210 processed successfully.
# Processing session 211
# Session 211 processed successfully.
# Processing session 212
# Session 212 processed successfully.
# Processing session 213
# Session 213 processed successfully.
# Processing session 214
# Session 214 processed successfully.
# Processing session 215
# Session 215 processed successfully.
# Processing session 216
# Session 216 processed successfully.
# Processing session 217
# Session 217 processed successfully.
# Processing session 218
# Session 218 processed successfully.
# Processing session 219
# Session 219 processed successfully.
# Processing session 220
# Session 220 processed successfully.
# Processing session 221
# Session 221 processed successfully.
# Processing session 222
# Session 222 processed successfully.
# Processing session 223
# Session 223 processed successfully.
# Processing session 224
# Session 224 processed successfully.
# Processing session 225
# Session 225 processed successfully.
# Processing session 226
# Session 226 processed successfully.
# Processing session 227
# Session 227 processed successfully.
# Processing session 228
# Session 228 processed successfully.
# Processing session 229
# Session 229 processed successfully.
# Processing session 230
# Session 230 processed successfully.
# Processing session 231
# Session 231 processed successfully.
# Processing session 232
# Session 232 processed successfully.
# Processing session 233
# Session 233 processed successfully.
# Processing session 234
# Session 234 processed successfully.
# Processing session 235
# Session 235 processed successfully.
# Processing session 236
# Session 236 processed successfully.
# Processing session 237
# Session 237 processed successfully.
# Processing session 238
# Session 238 processed successfully.
# Processing session 239
# Session 239 processed successfully.
# Processing session 240
# Session 240 processed successfully.
# Processing session 241
# Session 241 processed successfully.
# Processing session 242
# Session 242 processed successfully.
# Processing session 243
# Session 243 processed successfully.
# Processing session 244
# Session 244 processed successfully.
# Processing session 245
# Session 245 processed successfully.
# Processing session 246
# Session 246 processed successfully.
# Processing session 247
# Session 247 processed successfully.
# Processing session 248
# Session 248 processed successfully.
# Processing session 249
# Session 249 processed successfully.
# Processing session 250
# Session 250 processed successfully.
# Processing session 251
# Session 251 processed successfully.
# Processing session 252
# Session 252 processed successfully.
# Processing session 253
# Session 253 processed successfully.
# Processing session 254
# Session 254 processed successfully.
# Processing session 255
# Session 255 processed successfully.
# Processing session 256
# Session 256 processed successfully.
# Processing session 257
# Session 257 processed successfully.
# Processing session 258
# Session 258 processed successfully.
# Processing session 259
# Session 259 processed successfully.
# Processing session 260
# Session 260 processed successfully.
# Processing session 261
# Session 261 processed successfully.
# Processing session 262
# Session 262 processed successfully.
# Processing session 263
# Session 263 processed successfully.
# Processing session 264
# Session 264 processed successfully.
# Processing session 265
# Session 265 processed successfully.
# Processing session 266
# Session 266 processed successfully.
# Processing session 267
# Session 267 processed successfully.
# Processing session 268
# Session 268 processed successfully.
# Processing session 269
# Session 269 processed successfully.
# Processing session 270
# Session 270 processed successfully.
# Processing session 271
# Session 271 processed successfully.
# Processing session 272
# Session 272 processed successfully.
# Processing session 273
# Session 273 processed successfully.
# Processing session 274
# Session 274 processed successfully.
# Processing session 275
# Session 275 processed successfully.
# Processing session 276
# Session 276 processed successfully.
# Processing session 277
# Session 277 processed successfully.
# Processing session 278
# Session 278 processed successfully.
# Processing session 279
# Session 279 processed successfully.
# Processing session 280
# Session 280 processed successfully.
# Processing session 281
# Session 281 processed successfully.
# Processing session 282
# Session 282 processed successfully.
# Processing session 283
# Session 283 processed successfully.
# Processing session 284
# Session 284 processed successfully.
# Processing session 285
# Session 285 processed successfully.
# Processing session 286
# Session 286 processed successfully.
# Processing session 287
# Session 287 processed successfully.
# Processing session 288
# Session 288 processed successfully.
# Processing session 289
# Session 289 processed successfully.
# Processing session 290
# Session 290 processed successfully.
# Processing session 291
# Session 291 processed successfully.
# Processing session 292
# Session 292 processed successfully.
# Processing session 293
# Session 293 processed successfully.
# Processing session 294
# Session 294 processed successfully.
# Processing session 295
# Session 295 processed successfully.
# Processing session 296
# Session 296 processed successfully.
# Processing session 297
# Session 297 processed successfully.
# Processing session 298
# Session 298 processed successfully.
# Processing session 299
# Session 299 processed successfully.
# Processing session 300
# Session 300 processed successfully.
# Processing session 301
# Session 301 processed successfully.
# Processing session 302
# Session 302 processed successfully.
# Processing session 303
# Session 303 processed successfully.
# Processing session 304
# Session 304 processed successfully.
# Processing session 305
# Session 305 processed successfully.
# Processing session 306
# Session 306 processed successfully.
# Processing session 307
# Session 307 processed successfully.
# Processing session 308
# Session 308 processed successfully.
# Processing session 309
# Session 309 processed successfully.
# Processing session 310
# Session 310 processed successfully.
# Processing session 311
# Session 311 processed successfully.
# Processing session 312
# Session 312 processed successfully.
# Processing session 313
# Session 313 processed successfully.
# Processing session 314
# Session 314 processed successfully.
# Processing session 315
# Session 315 processed successfully.
# Processing session 316
# Session 316 processed successfully.
# Processing session 317
# Session 317 processed successfully.
# Processing session 318
# Session 318 processed successfully.
# Processing session 319
# Session 319 processed successfully.
# Processing session 320
# Session 320 processed successfully.
# Processing session 321
# Session 321 processed successfully.
# Processing session 322
# Session 322 processed successfully.
# Processing session 323
# Session 323 processed successfully.
# Processing session 324
# Session 324 processed successfully.
# Processing session 325
# Session 325 processed successfully.
# Processing session 326
# Session 326 processed successfully.
# Processing session 327
# Session 327 processed successfully.
# Processing session 328
# Session 328 processed successfully.
# Processing session 329
# Session 329 processed successfully.
# Processing session 330
# Session 330 processed successfully.
# Processing session 331
# Session 331 processed successfully.
# Processing session 332
# Session 332 processed successfully.
# Processing session 333
# Session 333 processed successfully.
# Processing session 334
# Session 334 processed successfully.
# Processing session 335
# Session 335 processed successfully.
# Processing session 336
# Session 336 processed successfully.
# Processing session 337
# Session 337 processed successfully.
# Processing session 338
# Session 338 processed successfully.
# Processing session 339
# Session 339 processed successfully.
# Processing session 340
# Session 340 processed successfully.
# Processing session 341
# Session 341 processed successfully.
# Processing session 342
# Session 342 processed successfully.
# Processing session 343
# Session 343 processed successfully.
# Processing session 344
# Session 344 processed successfully.
# Processing session 345
# Session 345 processed successfully.
# Processing session 346
# Session 346 processed successfully.
# Processing session 347
# Session 347 processed successfully.
# Processing session 348
# Session 348 processed successfully.
# Processing session 349
# Session 349 processed successfully.
# Processing session 350
# Session 350 processed successfully.
# Processing session 351
# Session 351 processed successfully.
# Processing session 352
# Session 352 processed successfully.
# Processing session 353
# Session 353 processed successfully.
# Processing session 354
# Session 354 processed successfully.
# Processing session 355
# Session 355 processed successfully.
# Processing session 356
# Session 356 processed successfully.
# Processing session 357
# Session 357 processed successfully.
# Processing session 358
# Session 358 processed successfully.
# Processing session 359
# Session 359 processed successfully.
# Processing session 360
# Session 360 processed successfully.
# Processing session 361
# Session 361 processed successfully.
# Processing session 362
# Session 362 processed successfully.
# Processing session 363
# Session 363 processed successfully.
# Processing session 364
# Session 364 processed successfully.
# Processing session 365
# Session 365 processed successfully.
# Processing session 366
# Session 366 processed successfully.
# Processing session 367
# Session 367 processed successfully.
# Processing session 368
# Session 368 processed successfully.
# Processing session 369
# Session 369 processed successfully.
# Processing session 370
# Session 370 processed successfully.
# Processing session 371
# Session 371 processed successfully.
# Processing session 372
# Session 372 processed successfully.
# Processing session 373
# Session 373 processed successfully.
# Processing session 374
# Session 374 processed successfully.
# Processing session 375
# Session 375 processed successfully.
# Processing session 376
# Session 376 processed successfully.
# Processing session 377
# Session 377 processed successfully.
# Processing session 378
# Session 378 processed successfully.
# Processing session 379
# Session 379 processed successfully.
# Processing session 380
# Session 380 processed successfully.
# Processing session 381
# Session 381 processed successfully.
# Processing session 382
# Session 382 processed successfully.
# Processing session 383
# Session 383 processed successfully.
# Processing session 384
# Session 384 processed successfully.
# Processing session 385
# Session 385 processed successfully.
# Processing session 386
# Session 386 processed successfully.
# Processing session 387
# Session 387 processed successfully.
# Processing session 388
# Session 388 processed successfully.
# Processing session 389
# Session 389 processed successfully.
# Processing session 390
# Session 390 processed successfully.
# Processing session 391
# Session 391 processed successfully.
# Processing session 392
# Session 392 processed successfully.
# Processing session 393
# Session 393 processed successfully.
# Processing session 394
# Session 394 processed successfully.
# Processing session 395
# Session 395 processed successfully.
# Processing session 396
# Session 396 processed successfully.
# Processing session 397
# Session 397 processed successfully.
# Processing session 398
# Session 398 processed successfully.
# Processing session 399
# Session 399 processed successfully.
# Processing session 400
# Session 400 processed successfully.
# Processing session 401
# Session 401 processed successfully.
# Processing session 402
# Session 402 processed successfully.
# Processing session 403
# Session 403 processed successfully.
# Processing session 404
# Session 404 processed successfully.
# Processing session 405
# Session 405 processed successfully.
# Processing session 406
# Session 406 processed successfully.
# Processing session 407
# Session 407 processed successfully.
# Processing session 408
# Session 408 processed successfully.
# Processing session 409
# Session 409 processed successfully.
# Processing session 410
# Session 410 processed successfully.
# Processing session 411
# Session 411 processed successfully.
# Processing session 412
# Session 412 processed successfully.
# Processing session 413
# Session 413 processed successfully.
# Processing session 414
# Session 414 processed successfully.
# Processing session 415
# Session 415 processed successfully.
# Processing session 416
# Session 416 processed successfully.
# Processing session 417
# Session 417 processed successfully.
# Processing session 418
# Session 418 processed successfully.
# Processing session 419
# Session 419 processed successfully.
# Processing session 420
# Session 420 processed successfully.
# Processing session 421
# Session 421 processed successfully.
# Processing session 422
# Session 422 processed successfully.
# Processing session 423
# Session 423 processed successfully.
# Processing session 424
# Session 424 processed successfully.
# Processing session 425
# Session 425 processed successfully.
# Processing session 426
# Session 426 processed successfully.
# Processing session 427
# Session 427 processed successfully.
# Processing session 428
# Session 428 processed successfully.
# Processing session 429
# Session 429 processed successfully.
# Processing session 430
# Session 430 processed successfully.
# Processing session 431
# Session 431 processed successfully.
# Processing session 432
# Session 432 processed successfully.
# Processing session 433
# Session 433 processed successfully.
# Processing session 434
# Session 434 processed successfully.
# Processing session 435
# Session 435 processed successfully.
# Processing session 436
# Session 436 processed successfully.
# Processing session 437
# Session 437 processed successfully.
# Processing session 438
# Session 438 processed successfully.
# Processing session 439
# Session 439 processed successfully.
# Processing session 440
# Session 440 processed successfully.
# Processing session 441
# Session 441 processed successfully.
# Processing session 442
# Session 442 processed successfully.
# Processing session 443
# Session 443 processed successfully.
# Processing session 444
# Session 444 processed successfully.
# Processing session 445
# Session 445 processed successfully.
# Processing session 446
# Session 446 processed successfully.
# Processing session 447
# Session 447 processed successfully.
# Processing session 448
# Session 448 processed successfully.
# Processing session 449
# Session 449 processed successfully.
# Processing session 450
# Session 450 processed successfully.
# Processing session 451
# Session 451 processed successfully.
# Processing session 452
# Session 452 processed successfully.
# Processing session 453
# Session 453 processed successfully.
# Processing session 454
# Session 454 processed successfully.
# Processing session 455
# Session 455 processed successfully.
# Processing session 456
# Session 456 processed successfully.
# Processing session 457
# Session 457 processed successfully.
# Processing session 458
# Session 458 processed successfully.
# Processing session 459
# Session 459 processed successfully.
# Processing session 460
# Session 460 processed successfully.
# Processing session 461
# Session 461 processed successfully.
# Processing session 462
# Session 462 processed successfully.
# Processing session 463
# Session 463 processed successfully.
# Processing session 464
# Session 464 processed successfully.
# Processing session 465
# Session 465 processed successfully.
# Processing session 466
# Session 466 processed successfully.
# Processing session 467
# Session 467 processed successfully.
# Processing session 468
# Session 468 processed successfully.
# Processing session 469
# Session 469 processed successfully.
# Processing session 470
# Session 470 processed successfully.
# Processing session 471
# Session 471 processed successfully.
# Processing session 472
# Session 472 processed successfully.
# Processing session 473
# Session 473 processed successfully.
# Processing session 474
# Session 474 processed successfully.
# Processing session 475
# Session 475 processed successfully.
# Processing session 476
# Session 476 processed successfully.
# Processing session 477
# Session 477 processed successfully.
# Processing session 478
# Session 478 processed successfully.
# Processing session 479
# Session 479 processed successfully.
# Processing session 480
# Session 480 processed successfully.
# Processing session 481
# Session 481 processed successfully.
# Processing session 482
# Session 482 processed successfully.
# Processing session 483
# Session 483 processed successfully.
# Processing session 484
# Session 484 processed successfully.
# Processing session 485
# Session 485 processed successfully.
# Processing session 486
# Session 486 processed successfully.
# Processing session 487
# Session 487 processed successfully.
# Processing session 488
# Session 488 processed successfully.
# Processing session 489
# Session 489 processed successfully.
# Processing session 490
# Session 490 processed successfully.
# Processing session 491
# Session 491 processed successfully.
# Processing session 492
# Session 492 processed successfully.
# Processing session 493
# Session 493 processed successfully.
# Processing session 494
# Session 494 processed successfully.
# Processing session 495
# Session 495 processed successfully.
# Processing session 496
# Session 496 processed successfully.
# Processing session 497
# Session 497 processed successfully.
# Processing session 498
# Session 498 processed successfully.
# Processing session 499
# Session 499 processed successfully.
# Processing session 500
# Session 500 processed successfully.
# Processing session 501
# Session 501 processed successfully.
# Processing session 502
# Session 502 processed successfully.
# Processing session 503
# Session 503 processed successfully.
# Processing session 504
# Session 504 processed successfully.
# Processing session 505
# Session 505 processed successfully.
# Processing session 506
# Session 506 processed successfully.
# Processing session 507
# Session 507 processed successfully.
# Processing session 508
# Session 508 processed successfully.
# Processing session 509
# Session 509 processed successfully.
# Processing session 510
# Session 510 processed successfully.
# Processing session 511
# Session 511 processed successfully.
# Processing session 512
# Session 512 processed successfully.
# Processing session 513
# Session 513 processed successfully.
# Processing session 514
# Session 514 processed successfully.
# Processing session 515
# Session 515 processed successfully.
# Processing session 516
# Session 516 processed successfully.
# Processing session 517
# Session 517 processed successfully.
# Processing session 518
# Session 518 processed successfully.
# Processing session 519
# Session 519 processed successfully.
# Processing session 520
# Session 520 processed successfully.
# Processing session 521
# Session 521 processed successfully.
# Processing session 522
# Session 522 processed successfully.
# Processing session 523
# Session 523 processed successfully.
# Processing session 524
# Session 524 processed successfully.
# Processing session 525
# Session 525 processed successfully.
# Processing session 526
# Session 526 processed successfully.
# Processing session 527
# Session 527 processed successfully.
# Processing session 528
# Session 528 processed successfully.
# Processing session 529
# Session 529 processed successfully.
# Processing session 530
# Session 530 processed successfully.
# Processing session 531
# Session 531 processed successfully.
# Processing session 532
# Session 532 processed successfully.
# Processing session 533
# Session 533 processed successfully.
# Processing session 534
# Session 534 processed successfully.
# Processing session 535
# Session 535 processed successfully.
# Processing session 536
# Session 536 processed successfully.
# Processing session 537
# Session 537 processed successfully.
# Processing session 538
# Session 538 processed successfully.
# Processing session 539
# Session 539 processed successfully.
# Processing session 540
# Session 540 processed successfully.
# Processing session 541
# Session 541 processed successfully.
# Processing session 542
# Session 542 processed successfully.
# Processing session 543
# Session 543 processed successfully.
# Processing session 544
# Session 544 processed successfully.
# Processing session 545
# Session 545 processed successfully.
# Processing session 546
# Session 546 processed successfully.
# Processing session 547
# Session 547 processed successfully.
# Processing session 548
# Session 548 processed successfully.
# Processing session 549
# Session 549 processed successfully.
# Processing session 550
# Session 550 processed successfully.
# Processing session 551
# Session 551 processed successfully.
# Processing session 552
# Session 552 processed successfully.
# Processing session 553
# Session 553 processed successfully.
# Processing session 554
# Session 554 processed successfully.
# Processing session 555
# Session 555 processed successfully.
# Processing session 556
# Session 556 processed successfully.
# Processing session 557
# Session 557 processed successfully.
# Processing session 558
# Session 558 processed successfully.
# Processing session 559
# Session 559 processed successfully.
# Processing session 560
# Session 560 processed successfully.
# Processing session 561
# Session 561 processed successfully.
# Processing session 562
# Session 562 processed successfully.
# Processing session 563
# Session 563 processed successfully.
# Processing session 564
# Session 564 processed successfully.
# Processing session 565
# Session 565 processed successfully.
# Processing session 566
# Session 566 processed successfully.
# Processing session 567
# Session 567 processed successfully.
# Processing session 568
# Session 568 processed successfully.
# Processing session 569
# Session 569 processed successfully.
# Processing session 570
# Session 570 processed successfully.
# Processing session 571
# Session 571 processed successfully.
# Processing session 572
# Session 572 processed successfully.
# Processing session 573
# Session 573 processed successfully.
# Processing session 574
# Session 574 processed successfully.
# Processing session 575
# Session 575 processed successfully.
# Processing session 576
# Session 576 processed successfully.
# Processing session 577
# Session 577 processed successfully.
# Processing session 578
# Session 578 processed successfully.
# Processing session 579
# Session 579 processed successfully.
# Processing session 580
# Session 580 processed successfully.
# Processing session 581
# Session 581 processed successfully.
# Processing session 582
# Session 582 processed successfully.
# Processing session 583
# Session 583 processed successfully.
# Processing session 584
# Session 584 processed successfully.
# Processing session 585
# Session 585 processed successfully.
# Processing session 586
# Session 586 processed successfully.
# Processing session 587
# Session 587 processed successfully.
# Processing session 588
# Session 588 processed successfully.
# Processing session 589
# Session 589 processed successfully.
# Processing session 590
# Session 590 processed successfully.
# Processing session 591
# Session 591 processed successfully.
# Processing session 592
# Session 592 processed successfully.
# Processing session 593
# Session 593 processed successfully.
# Processing session 594
# Session 594 processed successfully.
# Processing session 595
# Session 595 processed successfully.
# Processing session 596
# Session 596 processed successfully.
# Processing session 597
# Session 597 processed successfully.
# Processing session 598
# Session 598 processed successfully.
# Processing session 599
# Session 599 processed successfully.
# Processing session 600
# Session 600 processed successfully.
# Processing session 601
# Session 601 processed successfully.
# Processing session 602
# Session 602 processed successfully.
# Processing session 603
# Session 603 processed successfully.
# Processing session 604
# Session 604 processed successfully.
# Processing session 605
# Session 605 processed successfully.
# Processing session 606
# Session 606 processed successfully.
# Processing session 607
# Session 607 processed successfully.
# Processing session 608
# Session 608 processed successfully.
# Processing session 609
# Session 609 processed successfully.
# Processing session 610
# Session 610 processed successfully.
# Processing session 611
# Session 611 processed successfully.
# Processing session 612
# Session 612 processed successfully.
# Processing session 613
# Session 613 processed successfully.
# Processing session 614
# Session 614 processed successfully.
# Processing session 615
# Session 615 processed successfully.
# Processing session 616
# Session 616 processed successfully.
# Processing session 617
# Session 617 processed successfully.
# Processing session 618
# Session 618 processed successfully.
# Processing session 619
# Session 619 processed successfully.
# Processing session 620
# Session 620 processed successfully.
# Processing session 621
# Session 621 processed successfully.
# Processing session 622
# Session 622 processed successfully.
# Processing session 623
# Session 623 processed successfully.
# Processing session 624
# Session 624 processed successfully.
# Processing session 625
# Session 625 processed successfully.
# Processing session 626
# Session 626 processed successfully.
# Processing session 627
# Session 627 processed successfully.
# Processing session 628
# Session 628 processed successfully.
# Processing session 629
# Session 629 processed successfully.
# Processing session 630
# Session 630 processed successfully.
# Processing session 631
# Session 631 processed successfully.
# Processing session 632
# Session 632 processed successfully.
# Processing session 633
# Session 633 processed successfully.
# Processing session 634
# Session 634 processed successfully.
# Processing session 635
# Session 635 processed successfully.
# Processing session 636
# Session 636 processed successfully.
# Processing session 637
# Session 637 processed successfully.
# Processing session 638
# Session 638 processed successfully.
# Processing session 639
# Session 639 processed successfully.
# Processing session 640
# Session 640 processed successfully.
# Processing session 641
# Session 641 processed successfully.
# Processing session 642
# Session 642 processed successfully.
# Processing session 643
# Session 643 processed successfully.
# Processing session 644
# Session 644 processed successfully.
# Processing session 645
# Session 645 processed successfully.
# Processing session 646
# Session 646 processed successfully.
# Processing session 647
# Session 647 processed successfully.
# Processing session 648
# Session 648 processed successfully.
# Processing session 649
# Session 649 processed successfully.
# Processing session 650
# Session 650 processed successfully.
# Processing session 651
# Session 651 processed successfully.
# Processing session 652
# Session 652 processed successfully.
# Processing session 653
# Session 653 processed successfully.
# Processing session 654
# Session 654 processed successfully.
# Processing session 655
# Session 655 processed successfully.
# Processing session 656
# Session 656 processed successfully.
# Processing session 657
# Session 657 processed successfully.
# Processing session 658
# Session 658 processed successfully.
# Processing session 659
# Session 659 processed successfully.
# Processing session 660
# Session 660 processed successfully.
# Processing session 661
# Session 661 processed successfully.
# Processing session 662
# Session 662 processed successfully.
# Processing session 663
# Session 663 processed successfully.
# Processing session 664
# Session 664 processed successfully.
# Processing session 665
# Session 665 processed successfully.
# Processing session 666
# Session 666 processed successfully.
# Processing session 667
# Session 667 processed successfully.
# Processing session 668
# Session 668 processed successfully.
# Processing session 669
# Session 669 processed successfully.
# Processing session 670
# Session 670 processed successfully.
# Processing session 671
# Session 671 processed successfully.
# Processing session 672
# Session 672 processed successfully.
# Processing session 673
# Session 673 processed successfully.
# Processing session 674
# Session 674 processed successfully.
# Processing session 675
# Session 675 processed successfully.
# Processing session 676
# Session 676 processed successfully.
# Processing session 677
# Session 677 processed successfully.
# Processing session 678
# Session 678 processed successfully.
# Processing session 679
# Session 679 processed successfully.
# Processing session 680
# Session 680 processed successfully.
# Processing session 681
# Session 681 processed successfully.
# Processing session 682
# Session 682 processed successfully.
# Processing session 683
# Session 683 processed successfully.
# Processing session 684
# Session 684 processed successfully.
# Processing session 685
# Session 685 processed successfully.
# Processing session 686
# Session 686 processed successfully.
# Processing session 687
# Session 687 processed successfully.
# Processing session 688
# Session 688 processed successfully.
# Processing session 689
# Session 689 processed successfully.
# Processing session 690
# Session 690 processed successfully.
# Processing session 691
# Session 691 processed successfully.
# Processing session 692
# Session 692 processed successfully.
# Processing session 693
# Session 693 processed successfully.
# Processing session 694
# Session 694 processed successfully.
# Processing session 695
# Session 695 processed successfully.
# Processing session 696
# Session 696 processed successfully.
# Processing session 697
# Session 697 processed successfully.
# Processing session 698
# Session 698 processed successfully.
# Processing session 699
# Session 699 processed successfully.
# Processing session 700
# Session 700 processed successfully.
# Processing session 701
# Session 701 processed successfully.
# Processing session 702
# Session 702 processed successfully.
# Processing session 703
# Session 703 processed successfully.
# Processing session 704
# Session 704 processed successfully.
# Processing session 705
# Session 705 processed successfully.
# Processing session 706
# Session 706 processed successfully.
# Processing session 707
# Session 707 processed successfully.
# Processing session 708
# Session 708 processed successfully.
# Processing session 709
# Session 709 processed successfully.
# Processing session 710
# Session 710 processed successfully.
# Processing session 711
# Session 711 processed successfully.
# Processing session 712
# Session 712 processed successfully.
# Processing session 713
# Session 713 processed successfully.
# Processing session 714
# Session 714 processed successfully.
# Processing session 715
# Session 715 processed successfully.
# Processing session 716
# Session 716 processed successfully.
# Processing session 717
# Session 717 processed successfully.
# Processing session 718
# Session 718 processed successfully.
# Processing session 719
# Session 719 processed successfully.
# Processing session 720
# Session 720 processed successfully.
# Processing session 721
# Session 721 processed successfully.
# Processing session 722
# Session 722 processed successfully.
# Processing session 723
# Session 723 processed successfully.
# Processing session 724
# Session 724 processed successfully.
# Processing session 725
# Session 725 processed successfully.
# Processing session 726
# Session 726 processed successfully.
# Processing session 727
# Session 727 processed successfully.
# Processing session 728
# Session 728 processed successfully.
# Processing session 729
# Session 729 processed successfully.
# Processing session 730
# Session 730 processed successfully.
# Processing session 731
# Session 731 processed successfully.
# Processing session 732
# Session 732 processed successfully.
# Processing session 733
# Session 733 processed successfully.
# Processing session 734
# Session 734 processed successfully.
# Processing session 735
# Session 735 processed successfully.
# Processing session 736
# Session 736 processed successfully.
# Processing session 737
# Session 737 processed successfully.
# Processing session 738
# Session 738 processed successfully.
# Processing session 739
# Session 739 processed successfully.
# Processing session 740
# Session 740 processed successfully.
# Processing session 741
# Session 741 processed successfully.
# Processing session 742
# Session 742 processed successfully.
# Processing session 743
# Session 743 processed successfully.
# Processing session 744
# Session 744 processed successfully.
# Processing session 745
# Session 745 processed successfully.
# Processing session 746
# Session 746 processed successfully.
# Processing session 747
# Session 747 processed successfully.
# Processing session 748
# Session 748 processed successfully.
# Processing session 749
# Session 749 processed successfully.
# Processing session 750
# Session 750 processed successfully.
# Processing session 751
# Session 751 processed successfully.
# Processing session 752
# Session 752 processed successfully.
# Processing session 753
# Session 753 processed successfully.
# Processing session 754
# Session 754 processed successfully.
# Processing session 755
# Session 755 processed successfully.
# Processing session 756
# Session 756 processed successfully.
# Processing session 757
# Session 757 processed successfully.
# Processing session 758
# Session 758 processed successfully.
# Processing session 759
# Session 759 processed successfully.
# Processing session 760
# Session 760 processed successfully.
# Processing session 761
# Session 761 processed successfully.
# Processing session 762
# Session 762 processed successfully.
# Processing session 763
# Session 763 processed successfully.
# Processing session 764
# Session 764 processed successfully.
# Processing session 765
# Session 765 processed successfully.
# Processing session 766
# Session 766 processed successfully.
# Processing session 767
# Session 767 processed successfully.
# Processing session 768
# Session 768 processed successfully.
# Processing session 769
# Session 769 processed successfully.
# Processing session 770
# Session 770 processed successfully.
# Processing session 771
# Session 771 processed successfully.
# Processing session 772
# Session 772 processed successfully.
# Processing session 773
# Session 773 processed successfully.
# Processing session 774
# Session 774 processed successfully.
# Processing session 775
# Session 775 processed successfully.
# Processing session 776
# Session 776 processed successfully.
# Processing session 777
# Session 777 processed successfully.
# Processing session 778
# Session 778 processed successfully.
# Processing session 779
# Session 779 processed successfully.
# Processing session 780
# Session 780 processed successfully.
# Processing session 781
# Session 781 processed successfully.
# Processing session 782
# Session 782 processed successfully.
# Processing session 783
# Session 783 processed successfully.
# Processing session 784
# Session 784 processed successfully.
# Processing session 785
# Session 785 processed successfully.
# Processing session 786
# Session 786 processed successfully.
# Processing session 787
# Session 787 processed successfully.
# Processing session 788
# Session 788 processed successfully.
# Processing session 789
# Session 789 processed successfully.
# Processing session 790
# Session 790 processed successfully.
# Processing session 791
# Session 791 processed successfully.
# Processing session 792
# Session 792 processed successfully.
# Processing session 793
# Session 793 processed successfully.
# Processing session 794
# Session 794 processed successfully.
# Processing session 795
# Session 795 processed successfully.
# Processing session 796
# Session 796 processed successfully.
# Processing session 797
# Session 797 processed successfully.
# Processing session 798
# Session 798 processed successfully.
# Processing session 799
# Session 799 processed successfully.
# Processing session 800
# Session 800 processed successfully.
# Processing session 801
# Session 801 processed successfully.
# Processing session 802
# Session 802 processed successfully.
# Processing session 803
# Session 803 processed successfully.
# Processing session 804
# Session 804 processed successfully.
# Processing session 805
# Session 805 processed successfully.
# Processing session 806
# Session 806 processed successfully.
# Processing session 807
# Session 807 processed successfully.
# Processing session 808
# Session 808 processed successfully.
# Processing session 809
# Session 809 processed successfully.
# Processing session 810
# Session 810 processed successfully.
# Processing session 811
# Session 811 processed successfully.
# ...
# Processing session 037
# Session 037 processed successfully.
# Processing session 038
# Session 038 processed successfully.
# Processing session 039
# Session 039 processed successfully.
# Processing session 040
# Session 040 processed successfully.
# Processing session 041
# Session 041 processed successfully.
# Processing session 042
# Session 042 processed successfully.
# Processing session 043
# Session 043 processed successfully.
# Processing session 044
# Session 044 processed successfully.
# Processing session 045
# Session 045 processed successfully.
# Processing session 046
# Session 046 processed successfully.
# Processing session 047
# Session 047 processed successfully.
# Processing session 048
# Session 048 processed successfully.
# Processing session 049
# Session 049 processed successfully.
# Processing session 050
# Session 050 processed successfully.
# Processing session 051
# Session 051 processed successfully.
# Processing session 052
# Session 052 processed successfully.
# Processing session 053
# Session 053 processed successfully.
# Processing session 054
# Session 054 processed successfully.
# Processing session 055
# Session 055 processed successfully.
# Processing session 056
# Session 056 processed successfully.
# Processing session 057
# Session 057 processed successfully.
# Processing session 058
# Session 058 processed successfully.
# Processing session 059
# Session 059 processed successfully.
# Processing session 060
# Session 060 processed successfully.
# Processing session 061
# Session 061 processed successfully.
# Processing session 062
# Session 062 processed successfully.
# Processing session 063
# Session 063 processed successfully.
# Processing session 064
# Session 064 processed successfully.
# Processing session 065
# Session 065 processed successfully.
# Processing session 066
# Session 066 processed successfully.
# Processing session 067
# Session 067 processed successfully.
# Processing session 068
# Session 068 processed successfully.
# Processing session 069
# Session 069 processed successfully.
# Processing session 070
# Session 070 processed successfully.
# Processing session 071
# Session 071 processed successfully.
# Processing session 072
# Session 072 processed successfully.
# Processing session 073
# Session 073 processed successfully.
# Processing session 074
# Session 074 processed successfully.
# Processing session 075
# Session 075 processed successfully.
# Processing session 076
# Session 076 processed successfully.
# Processing session 077
# Session 077 processed successfully.
# Processing session 078
# Session 078 processed successfully.
# Processing session 079
# Session 079 processed successfully.
# Processing session 080
# Session 080 processed successfully.
# Processing session 081
# Session 081 processed successfully.
# Processing session 082
# Session 082 processed successfully.
# Processing session 083
# Session 083 processed successfully.
# Processing session 084
# Session 084 processed successfully.
# Processing session 085
# Session 085 processed successfully.
# Processing session 086
# Session 086 processed successfully.
# Processing session 087
# Session 087 processed successfully.
# Processing session 088
# Session 088 processed successfully.
# Processing session 089
# Session 089 processed successfully.
# Processing session 090
# Session 090 processed successfully.
# Processing session 091
# Session 091 processed successfully.
# Processing session 092
# Session 092 processed successfully.
# Processing session 093
# Session 093 processed successfully.
# Processing session 094
# Session 094 processed successfully.
# Processing session 095
# Session 095 processed successfully.
# Processing session 096
# Session 096 processed successfully.
# Processing session 097
# Session 097 processed successfully.
# Processing session 098
# Session 098 processed successfully.
# Processing session 099
# Session 099 processed successfully.
# Processing session 100
# Session 100 processed successfully.
# Processing session 101
# Session 101 processed successfully.
# Processing session 102
# Session 102 processed successfully.
# Processing session 103
# Session 103 processed successfully.
# Processing session 104
# Session 104 processed successfully.
# Processing session 105
# Session 105 processed successfully.
# Processing session 106
# Session 106 processed successfully.
# Processing session 107
# Session 107 processed successfully.
# Processing session 108
# Session 108 processed successfully.
# Processing session 109
# Session 109 processed successfully.
# Processing session 110
# Session 110 processed successfully.
# Processing session 111
# Session 111 processed successfully.
# Processing session 112
# Session 112 processed successfully.
# Processing session 113
# Session 113 processed successfully.
# Processing session 114
# Session 114 processed successfully.
# Processing session 115
# Session 115 processed successfully.
# Processing session 116
# Session 116 processed successfully.
# Processing session 117
# Session 117 processed successfully.
# Processing session 118
# Session 118 processed successfully.
# Processing session 119
# Session 119 processed successfully.
# Processing session 120
# Session 120 processed successfully.
# Processing session 121
# Session 121 processed successfully.
# Processing session 122
# Session 122 processed successfully.
# Processing session 123
# Session 123 processed successfully.
# Processing session 124
# Session 124 processed successfully.
# Processing session 125
# Session 125 processed successfully.
# Processing session 126
# Session 126 processed successfully.
# Processing session 127
# Session 127 processed successfully.
# Processing session 128
# Session 128 processed successfully.
# Processing session 129
# Session 129 processed successfully.
# Processing session 130
# Session 130 processed successfully.
# Processing session 131
# Session 131 processed successfully.
# Processing session 132
# Session 132 processed successfully.
# Processing session 133
# Session 133 processed successfully.
# Processing session 134
# Session 134 processed successfully.
# Processing session 135
# Session 135 processed successfully.
# Processing session 136
# Session 136 processed successfully.
# Processing session 137
# Session 137 processed successfully.
# Processing session 138
# Session 138 processed successfully.
# Processing session 139
# Session 139 processed successfully.
# Processing session 140
# Session 140 processed successfully.
# Processing session 141
# Session 141 processed successfully.
# Processing session 142
# Session 142 processed successfully.
# Processing session 143
# Session 143 processed successfully.
# Processing session 144
# Session 144 processed successfully.
# Processing session 145
# Session 145 processed successfully.
# Processing session 146
# Session 146 processed successfully.
# Processing session 147
# Session 147 processed successfully.
# Processing session 148
# Session 148 processed successfully.
# Processing session 149
# Session 149 processed successfully.
# Processing session 150
# Session 150 processed successfully.
# Processing session 151
# Session 151 processed successfully.
# Processing session 152
# Session 152 processed successfully.
# Processing session 153
# Session 153 processed successfully.
# Processing session 154
# Session 154 processed successfully.
# Processing session 155
# Session 155 processed successfully.
# Processing session 156
# Session 156 processed successfully.
# Processing session 157
# Session 157 processed successfully.
# Processing session 158
# Session 158 processed successfully.
# Processing session 159
# Session 159 processed successfully.
# Processing session 160
# Session 160 processed successfully.
# Processing session 161
# Session 161 processed successfully.
# Processing session 162
# Session 162 processed successfully.
# Processing session 163
# Session 163 processed successfully.
# Processing session 164
# Session 164 processed successfully.
# Processing session 165
# Session 165 processed successfully.
# Processing session 166
# Session 166 processed successfully.
# Processing session 167
# Session 167 processed successfully.
# Processing session 168
# Session 168 processed successfully.
# Processing session 169
# Session 169 processed successfully.
# Processing session 170
# Session 170 processed successfully.
# Processing session 171
# Session 171 processed successfully.
# Processing session 172
# Session 172 processed successfully.
# Processing session 173
# Session 173 processed successfully.
# Processing session 174
# Session 174 processed successfully.
# Processing session 175
# Session 175 processed successfully.
# Processing session 176
# Session 176 processed successfully.
# Processing session 177
# Session 177 processed successfully.
# Processing session 178
# Session 178 processed successfully.
# Processing session 179
# Session 179 processed successfully.
# Processing session 180
# Session 180 processed successfully.
# Processing session 181
# Session 181 processed successfully.
# Processing session 182
# Session 182 processed successfully.
# Processing session 183
# Session 183 processed successfully.
# Processing session 184
# Session 184 processed successfully.
# Processing session 185
# Session 185 processed successfully.
# Processing session 186
# Session 186 processed successfully.
# Processing session 187
# Session 187 processed successfully.
# Processing session 188
# Session 188 processed successfully.
# Processing session 189
# Session 189 processed successfully.
# Processing session 190
# Session 190 processed successfully.
# Processing session 191
# Session 191 processed successfully.
# Processing session 192
# Session 192 processed successfully.
# Processing session 193
# Session 193 processed successfully.
# Processing session 194
# Session 194 processed successfully.
# Processing session 195
# Session 195 processed successfully.
# Processing session 196
# Session 196 processed successfully.
# Processing session 197
# Session 197 processed successfully.
# Processing session 198
# Session 198 processed successfully.
# Processing session 199
# Session 199 processed successfully.
# Processing session 200
# Session 200 processed successfully.
# Processing session 201
# Session 201 processed successfully.
# Processing session 202
# Session 202 processed successfully.
# Processing session 203
# Session 203 processed successfully.
# Processing session 204
# Session 204 processed successfully.
# Processing session 205
# Session 205 processed successfully.
# Processing session 206
# Session 206 processed successfully.
# Processing session 207
# Session 207 processed successfully.
# Processing session 208
# Session 208 processed successfully.
# Processing session 209
# Session 209 processed successfully.
# Processing session 210
# Session 210 processed successfully.
# Processing session 211
# Session 211 processed successfully.
# Processing session 212
# Session 212 processed successfully.
# Processing session 213
# Session 213 processed successfully.
# Processing session 214
# Session 214 processed successfully.
# Processing session 215
# Session 215 processed successfully.
# Processing session 216
# Session 216 processed successfully.
# Processing session 217
# Session 217 processed successfully.
# Processing session 218
# Session 218 processed successfully.
# Processing session 219
# Session 219 processed successfully.
# Processing session 220
# Session 220 processed successfully.
# Processing session 221
# Session 221 processed successfully.
# Processing session 222
# Session 222 processed successfully.
# Processing session 223
# Session 223 processed successfully.
# Processing session 224
# Session 224 processed successfully.
# Processing session 225
# Session 225 processed successfully.
# Processing session 226
# Session 226 processed successfully.
# Processing session 227
# Session 227 processed successfully.
# Processing session 228
# Session 228 processed successfully.
# Processing session 229
# Session 229 processed successfully.
# Processing session 230
# Session 230 processed successfully.
# Processing session 231
# Session 231 processed successfully.
# Processing session 232
# Session 232 processed successfully.
# Processing session 233
# Session 233 processed successfully.
# Processing session 234
# Session 234 processed successfully.
# Processing session 235
# Session 235 processed successfully.
# Processing session 236
# Session 236 processed successfully.
# Processing session 237
# Session 237 processed successfully.
# Processing session 238
# Session 238 processed successfully.
# Processing session 239
# Session 239 processed successfully.
# Processing session 240
# Session 240 processed successfully.
# Processing session 241
# Session 241 processed successfully.
# Processing session 242
# Session 242 processed successfully.
# Processing session 243
# Session 243 processed successfully.
# Processing session 244
# Session 244 processed successfully.
# Processing session 245
# Session 245 processed successfully.
# Processing session 246
# Session 246 processed successfully.
# Processing session 247
# Session 247 processed successfully.
# Processing session 248
# Session 248 processed successfully.
# Processing session 249
# Session 249 processed successfully.
# Processing session 250
# Session 250 processed successfully.
# Processing session 251
# Session 251 processed successfully.
# Processing session 252
# Session 252 processed successfully.
# Processing session 253
# Session 253 processed successfully.
# Processing session 254
# Session 254 processed successfully.
# Processing session 255
# Session 255 processed successfully.
# Processing session 256
# Session 256 processed successfully.
# Processing session 257
# Session 257 processed successfully.
# Processing session 258
# Session 258 processed successfully.
# Processing session 259
# Session 259 processed successfully.
# Processing session 260
# Session 260 processed successfully.
# Processing session 261
# Session 261 processed successfully.
# Processing session 262
# Session 262 processed successfully.
# Processing session 263
# Session 263 processed successfully.
# Processing session 264
# Session 264 processed successfully.
# Processing session 265
# Session 265 processed successfully.
# Processing session 266
# Session 266 processed successfully.
# Processing session 267
# Session 267 processed successfully.
# Processing session 268
# Session 268 processed successfully.
# Processing session 269
# Session 269 processed successfully.
# Processing session 270
# Session 270 processed successfully.
# Processing session 271
# Session 271 processed successfully.
# Processing session 272
# Session 272 processed successfully.
# Processing session 273
# Session 273 processed successfully.
# Processing session 274
# Session 274 processed successfully.
# Processing session 275
# Session 275 processed successfully.
# Processing session 276
# Session 276 processed successfully.
# Processing session 277
# Session 277 processed successfully.
# Processing session 278
# Session 278 processed successfully.
# Processing session 279
# Session 279 processed successfully.
# Processing session 280
# Session 280 processed successfully.
# Processing session 281
# Session 281 processed successfully.
# Processing session 282
# Session 282 processed successfully.
# Processing session 283
# Session 283 processed successfully.
# Processing session 284
# Session 284 processed successfully.
# Processing session 285
# Session 285 processed successfully.
# Processing session 286
# Session 286 processed successfully.
# Processing session 287
# Session 287 processed successfully.
# Processing session 288
# Session 288 processed successfully.
# Processing session 289
# Session 289 processed successfully.
# Processing session 290
# Session 290 processed successfully.
# Processing session 291
# Session 291 processed successfully.
# Processing session 292
# Session 292 processed successfully.
# Processing session 293
# Session 293 processed successfully.
# Processing session 294
# Session 294 processed successfully.
# Processing session 295
# Session 295 processed successfully.
# Processing session 296
# Session 296 processed successfully.
# Processing session 297
# Session 297 processed successfully.
# Processing session 298
# Session 298 processed successfully.
# Processing session 299
# Session 299 processed successfully.
# Processing session 300
# Session 300 processed successfully.
# Processing session 301
# Session 301 processed successfully.
# Processing session 302
# Session 302 processed successfully.
# Processing session 303
# Session 303 processed successfully.
# Processing session 304
# Session 304 processed successfully.
# Processing session 305
# Session 305 processed successfully.
# Summary CSV successfully saved to /Volumes/One Touch/data/ipad_augusto | mac_luca/summary_features_histogram.csv

# %% [markdown]
# # LATEST processing

# %%
import os
import json
import pandas as pd
import numpy as np
import re
from scipy import stats
from scipy.signal import welch
import matplotlib.pyplot as plt  # For histogram computation (optional)

# ---------------------------
# Configuration and Setup
# ---------------------------

def load_config(config_path='config.json'):
    """
    Load configuration parameters from a JSON file.
    """
    if not os.path.exists(config_path):
        raise FileNotFoundError(f"Configuration file '{config_path}' not found.")
    
    with open(config_path, 'r') as f:
        config = json.load(f)
    
    required_keys = ['base_dir']
    for key in required_keys:
        if key not in config:
            raise KeyError(f"Missing required configuration key: '{key}'")
    
    return config

# ---------------------------
# Function to Convert Binary Data to DataFrame
# ---------------------------

def binary_to_dataframe(binary_filepath, input_range=1.0, adc_bits=16):
    """
    Convert a binary file containing interleaved CH1 and CH2 data into a DataFrame.

    Parameters:
        binary_filepath (str): Path to the binary file.
        input_range (float): Input range of the ADC (1:1 divider).
        adc_bits (int): Number of ADC bits

    Returns:
        pd.DataFrame: DataFrame containing voltage_ch1 and voltage_ch2.
    """
    # Read the binary file
    with open(binary_filepath, 'rb') as f:
        raw_data = f.read()
    
    # Convert to 16-bit integers
    samples = np.frombuffer(raw_data, dtype=np.int16)
    
    # Split interleaved data
    ch1_samples = samples[::2]  # Every other sample for CH1
    ch2_samples = samples[1::2]  # Every other sample for CH2

    # Convert raw ADC values to voltages
    voltage_ch1 = np.array(ch1_samples) * (input_range / (2**(adc_bits - 1)))
    voltage_ch2 = np.array(ch2_samples) * (input_range / (2**(adc_bits - 1)))
    
    # Create a DataFrame
    df = pd.DataFrame({
        'voltage_ch1': voltage_ch1,
        'voltage_ch2': voltage_ch2
    })
    
    return df

# ---------------------------
# Statistical Feature Computation
# ---------------------------

def compute_statistical_features(data_array):
    """
    Compute statistical features from a data array (e.g., power spectrum or histogram).
    """
    features = {}
    try:
        features['entropy'] = stats.entropy(np.abs(data_array))
        features['skewness'] = stats.skew(data_array)
        features['interquartile_range'] = np.percentile(data_array, 75) - np.percentile(data_array, 25)
        features['kurtosis'] = stats.kurtosis(data_array)
        features['percentile_75'] = np.percentile(data_array, 75)
        features['range'] = np.ptp(data_array)
        features['maximum'] = np.max(data_array)
        features['median'] = np.median(data_array)
        features['percentile_90'] = np.percentile(data_array, 90)
        features['mean_absolute_deviation'] = np.mean(np.abs(data_array - np.mean(data_array)))
    except Exception as e:
        print(f"Error computing statistical features: {e}")
        features = {key: np.nan for key in ['entropy', 'skewness', 'interquartile_range', 'kurtosis',
                                            'percentile_75', 'range', 'maximum', 'median',
                                            'percentile_90', 'mean_absolute_deviation']}
    return features

# ---------------------------
# Welch Processing Function
# ---------------------------

def process_welch(signal, sampling_rate):
    """
    Process the signal using Welch's method and compute the power spectrum.

    Parameters:
        signal (np.ndarray): The input signal.
        sampling_rate (float): The sampling rate of the signal.

    Returns:
        np.ndarray: Filtered power spectrum in dBm.
    """
    frequencies, power_spectrum = welch(signal, fs=sampling_rate, nperseg=1024)
    # Avoid log of zero by replacing zeros with a very small number
    power_spectrum = np.where(power_spectrum == 0, 1e-12, power_spectrum)
    power_dbm = 10 * np.log10(power_spectrum / 50)  # Assuming 50 ohm impedance
    mask = (frequencies >= 10e3) & (frequencies <= 100e3)
    filtered_data = power_dbm[mask]
    return filtered_data

# ---------------------------
# Histogram Processing Function
# ---------------------------

def process_histogram(signal):
    """
    Compute the histogram of the signal.

    Parameters:
        signal (np.ndarray): The input signal.

    Returns:
        np.ndarray: Histogram counts for feature computation.
    """
    hist_counts, bin_edges = np.histogram(signal, bins=50, density=True)
    data_to_analyze = hist_counts  # Use histogram counts for feature computation
    return data_to_analyze

# ---------------------------
# Channel Processing
# ---------------------------

def process_channel(signal, channel_label, decimation_factor, processing_method):
    """
    Process a single channel and return computed features.
    """
    try:
        if signal.size == 0:
            print(f"No data in {channel_label}")
            return None
        
        # Remove DC component
        signal = signal - np.mean(signal)

        sampling_rate = 125e6 / decimation_factor

        if processing_method.lower() == 'welch':
            filtered_data = process_welch(signal, sampling_rate)
        elif processing_method.lower() == 'hist':
            filtered_data = process_histogram(signal)
        else:
            raise ValueError(f"Invalid processing method: {processing_method}")

        # Compute statistical features
        features = compute_statistical_features(filtered_data)
        
        # Prefix feature names with channel label
        features = {f"{channel_label}_{key}": value for key, value in features.items()}
        
        return features

    except Exception as e:
        print(f"Error processing {channel_label}: {e}")
        return None

# ---------------------------
# Data Augmentation Function
# ---------------------------

def augment_signal(signal, augmentation_method='overlap', overlap_ratio=0.5):
    """
    Augment the signal using specified method.

    Parameters:
        signal (np.ndarray): The input signal.
        augmentation_method (str): The augmentation method to apply.
        overlap_ratio (float): The ratio of overlap between chunks.

    Returns:
        List[np.ndarray]: List of augmented signal chunks.
    """
    augmented_signals = []
    if augmentation_method == 'overlap':
        chunk_size = 10000  # Same as batch_size
        step_size = int(chunk_size * (1 - overlap_ratio))
        for start_idx in range(0, len(signal) - chunk_size + 1, step_size):
            end_idx = start_idx + chunk_size
            augmented_signals.append(signal[start_idx:end_idx])
    else:
        # Implement other augmentation methods if needed
        augmented_signals.append(signal)
    return augmented_signals

# ---------------------------
# Session Processing
# ---------------------------

def process_session(binary_filepath, decimation_factor, batch_size=10000, augment=False):
    """
    Process a single session by computing features for CH1 and CH2 in batches.

    Parameters:
        binary_filepath (str): Path to the binary file.
        decimation_factor (int): Decimation factor for signal processing.
        batch_size (int): Number of samples per batch.
        augment (bool): Whether to augment data using overlapping chunks.

    Returns:
        List[Dict]: List of dictionaries containing features for each batch.
    """
    session_data_list = []
    try:
        # Extract session number from filename
        session_match = re.search(r'session_(\d{3})\.bin', os.path.basename(binary_filepath))
        if not session_match:
            print(f"Invalid session filename format: {binary_filepath}")
            return None
        session_number = int(session_match.group(1))
        
        # Extract date from filepath
        date_str = os.path.basename(os.path.dirname(binary_filepath))
        
        # Read binary file into DataFrame
        df = binary_to_dataframe(binary_filepath)
        
        # Total number of samples
        total_samples = len(df)
        
        # If total_samples is less than batch_size, skip into the next session
        if total_samples < batch_size:
            print(f"Session {session_number} has less than {batch_size} samples. Skipping to next session.")
            return None
        
        # Determine the number of batches
        if augment:
            step_size = int(batch_size * 0.5)  # 50% overlap
            num_batches = (total_samples - batch_size) // step_size + 1
        else:
            num_batches = total_samples // batch_size
            step_size = batch_size

        for batch_index in range(num_batches):
            start_idx = batch_index * step_size
            end_idx = start_idx + batch_size

            # Skip if we don't have enough samples
            if end_idx > total_samples:
                break

            batch_df = df.iloc[start_idx:end_idx]

            batch_data = {}
            batch_data['session'] = session_number
            batch_data['date'] = date_str
            batch_data['batch'] = batch_index

            # Prepare data for CH1 and CH2
            ch1_signal = batch_df['voltage_ch1'].values
            ch2_signal = batch_df['voltage_ch2'].values

            # For each processing method (Welch and Histogram)
            for processing_method in ['welch', 'hist']:

                # Process CH1
                ch1_features = process_channel(ch1_signal, 'ch1', decimation_factor, processing_method)
                if ch1_features is None:
                    print(f"Failed to process CH1 for batch {batch_index} in session {session_number}")
                    continue

                # Process CH2
                ch2_features = process_channel(ch2_signal, 'ch2', decimation_factor, processing_method)
                if ch2_features is None:
                    print(f"Failed to process CH2 for batch {batch_index} in session {session_number}")
                    continue

                # Add features to batch_data with processing method suffix
                for key, value in ch1_features.items():
                    batch_data[f"{key}_{processing_method}"] = value

                for key, value in ch2_features.items():
                    batch_data[f"{key}_{processing_method}"] = value

            # Append batch_data to session_data_list
            session_data_list.append(batch_data)

    except Exception as e:
        print(f"Error processing session {binary_filepath}: {e}")
        return None

    return session_data_list

# ---------------------------
# Main Processing Function
# ---------------------------

def main():
    # Load configuration
    try:
        config = load_config('config.json')
    except (FileNotFoundError, KeyError, ValueError) as e:
        print(f"Configuration Error: {e}")
        return

    base_dir = config['base_dir']
    decimation_factor = config.get('decimation_factor', 1024)  # Default to 1024 if not specified
    batch_size = 10000

    # Prompt user for data augmentation
    augment_choice = input("Do you want to augment the data with overlapping chunks? (yes/no): ").strip().lower()
    if augment_choice in ['yes', 'y']:
        augment = True
        output_filename = 'summary_features_augmented.csv'
        print("Data augmentation enabled. Using overlapping chunks.")
    else:
        augment = False
        output_filename = 'summary_features.csv'
        print("Data augmentation disabled.")

    # Get list of devices in base_dir
    device_labels = [d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))]

    for device_label in device_labels:
        device_dir_path = os.path.join(base_dir, device_label)
        print(f"\nProcessing device: {device_label}")

        # Initialize a list to collect session data
        summary_data = []

        # Iterate over date directories
        date_dirs = [d for d in os.listdir(device_dir_path) if os.path.isdir(os.path.join(device_dir_path, d))]
        for date_dir in sorted(date_dirs):
            date_dir_path = os.path.join(device_dir_path, date_dir)

            print(f"Processing date directory: {date_dir_path}")

            # Find all session_###.bin files
            session_pattern = re.compile(r'session_(\d{3})\.bin')
            for filename in sorted(os.listdir(date_dir_path)):
                match = session_pattern.match(filename)
                if match:
                    session_number = match.group(1)
                    binary_filepath = os.path.join(date_dir_path, filename)

                    print(f"Processing session {session_number}")

                    # Process the session
                    session_data_list = process_session(binary_filepath, decimation_factor, batch_size, augment=augment)
                    if session_data_list:
                        for batch_data in session_data_list:
                            batch_data['device_label'] = device_label
                            summary_data.append(batch_data)
                        print(f"Session {session_number} processed successfully.")
                    else:
                        print(f"Failed to process session {session_number} in {date_dir_path}")

        if summary_data:
            # Convert the list of dictionaries to a DataFrame
            summary_df = pd.DataFrame(summary_data)

            # Define the output summary CSV path
            output_summary_path = os.path.join(base_dir, device_label, output_filename)

            # Save the summary DataFrame to CSV
            try:
                summary_df.to_csv(output_summary_path, index=False)
                print(f"Summary CSV successfully saved to {output_summary_path}")
            except Exception as e:
                print(f"Failed to save summary CSV: {e}")
        else:
            print(f"No data processed for device '{device_label}'.")

# ---------------------------
# Entry Point
# ---------------------------

if __name__ == "__main__":
    main()
# Out:
# Data augmentation disabled.
#
# Processing device: empty
# Processing date directory: /Volumes/One Touch/data_test/empty/2024-11-23
# Processing session 001
# Session 001 processed successfully.
# Processing session 002
# Session 002 processed successfully.
# Processing session 003
# Session 003 processed successfully.
# Processing session 004
# Session 004 processed successfully.
# Processing session 005
# Session 005 processed successfully.
# Processing session 006
# Session 006 processed successfully.
# Processing session 007
# Session 007 processed successfully.
# Processing session 008
# Session 008 processed successfully.
# Processing session 009
# Session 009 processed successfully.
# Processing session 010
# Session 010 processed successfully.
# Summary CSV successfully saved to /Volumes/One Touch/data_test/empty/summary_features.csv
