# %% [markdown]
# # generate data

# %%
import random
import json
from datetime import datetime, timedelta

# Define the list of devices (removed 'Air_conditioner')
devices = [
    'Ipad', 'Mac', 'Floor_lamp', 'Alexa', 'Speaker', 'TV3',
    'Microwave', 'Laptop charger1', 'Laptop charger2',
    'TV1', 'TV2', 'HVAC', 'Fridge', 'Dishwasher', 'Dryer',
    'Washer', 'Monitor', 'Playstation', 'Fan', 'Aspiradora',
    'Air fryer', 'Kettle', 'Rice cooker oven', 'Hot water heater'
]

# Define seasons based on month
def get_season(date):
    month = date.month
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

# Check if a day is weekend
def is_weekend(date):
    return date.weekday() >= 5  # 5 = Saturday, 6 = Sunday

# Initialize washer schedule: mapping week number to list of days (0=Monday,...6=Sunday)
washer_schedule = {}

# Helper function to assign two random days per week for washer usage
def assign_washer_days(year, week):
    if week in washer_schedule:
        return washer_schedule[week]
    # Assign two unique days for washer usage
    days = random.sample(range(7), 2)
    washer_schedule[week] = days
    return days

# Start and end times
start_time = datetime(2023, 11, 21, 0, 0, 0)
end_time = datetime(2024, 11, 21, 0, 0, 0)
time_interval = timedelta(minutes=10)

# Predefine some constants
DISHWASHER_START_HOUR = 20  # 8 PM
DISHWASHER_DURATION = timedelta(hours=1)  # Runs for 1 hour

# Rice cooker times (20 minutes before lunch and dinner)
LUNCH_TIME = datetime.strptime("12:00", "%H:%M").time()
DINNER_TIME = datetime.strptime("19:00", "%H:%M").time()
RICE_COOKER_DURATION = timedelta(minutes=20)

# Floor lamp on time
FLOOR_LAMP_START = 18  # 6 PM
FLOOR_LAMP_END = 23    # 11 PM

# Initialize schedule tracking variables
dishwasher_running = False
dishwasher_end_time = None

washer_running = False
washer_end_time = None
dryer_running = False
dryer_end_time = None

current_time = start_time

# Output JSON file path
output_file_path = 'synthetic_household_data.jsonl'

# Open the file in write mode
with open(output_file_path, 'w') as outfile:
    while current_time < end_time:
        season = get_season(current_time)
        week_number = current_time.isocalendar()[1]
        day_of_week = current_time.weekday()  # 0=Monday, 6=Sunday
        hour = current_time.hour
        minute = current_time.minute
        time = current_time.time()
        
        # Assign washer days per week
        washer_days = assign_washer_days(current_time.year, week_number)
        
        # Determine if today is a washer day
        is_washer_day = day_of_week in washer_days
        
        # Initialize label probabilities
        label_probabilities = {device: 0.0 for device in devices}
        
        # HVAC usage
        if season in ['Winter', 'Summer']:
            # HVAC nearly always on
            label_probabilities['HVAC'] = round(random.uniform(0.8, 1.0), 6)
        else:
            # HVAC on intermittently
            if random.random() < 0.7:  # 30% chance to be on
                label_probabilities['HVAC'] = round(random.uniform(0.8, 1.0), 6)
        
        # Fridge is always on but cycles; simulate with high probability
        label_probabilities['Fridge'] = round(random.uniform(0.8, 1.0), 6)
        
        # TVs on in the evening for a couple of hours
        if 18 <= hour < 23:
            label_probabilities['TV3'] = round(random.uniform(0.8, 1.0), 6)
            label_probabilities['TV1'] = round(random.uniform(0.8, 1.0), 6)
            label_probabilities['TV2'] = round(random.uniform(0.8, 1.0), 6)
        
        # Floor lamp on from 6 PM to 11 PM
        if FLOOR_LAMP_START <= hour < FLOOR_LAMP_END:
            label_probabilities['Floor_lamp'] = round(random.uniform(0.8, 1.0), 6)
        
        # Laptop chargers on during working hours and evening
        if 8 <= hour < 10 or 18 <= hour < 22:
            label_probabilities['Laptop charger1'] = round(random.uniform(0.8, 1.0), 6)
        if 8 <= hour < 10 or 18 <= hour < 22:
            label_probabilities['Laptop charger2'] = round(random.uniform(0.8, 1.0), 6)
        
        # Alexa and Speaker active in the evening
        if 18 <= hour < 23:
            label_probabilities['Alexa'] = round(random.uniform(0.8, 1.0), 6)
            label_probabilities['Speaker'] = round(random.uniform(0.8, 1.0), 6)
        
        # Fan active based on HVAC usage
        if label_probabilities['HVAC'] > 0:
            label_probabilities['Fan'] = round(random.uniform(0.8, 1.0), 6)
        
        # Aspiradora (vacuum cleaner) active on weekends, early morning
        if is_weekend(current_time) and 6 <= hour < 9:
            label_probabilities['Aspiradora'] = round(random.uniform(0.8, 1.0), 6)
        
        # Playstation active in the evening
        if 19 <= hour < 23:
            label_probabilities['Playstation'] = round(random.uniform(0.8, 1.0), 6)
        
        # Monitor active during laptop usage
        if label_probabilities['Laptop charger1'] > 0 or label_probabilities['Laptop charger2'] > 0:
            label_probabilities['Monitor'] = round(random.uniform(0.8, 1.0), 6)
        
        # Microwave usage: active randomly during meal times
        if (11 <= hour < 13) or (18 <= hour < 20):
            if random.random() < 0.3:  # 30% chance to be used
                label_probabilities['Microwave'] = round(random.uniform(0.8, 1.0), 6)
        
        # Air fryer usage: similar to microwave
        if (11 <= hour < 13) or (18 <= hour < 20):
            if random.random() < 0.2:  # 20% chance to be used
                label_probabilities['Air fryer'] = round(random.uniform(0.8, 1.0), 6)
        
        # Kettle active during morning and evening
        if (6 <= hour < 9) or (17 <= hour < 20):
            if random.random() < 0.5:  # 50% chance to be used
                label_probabilities['Kettle'] = round(random.uniform(0.8, 1.0), 6)
        
        # Rice cooker oven active 20 minutes before lunch and dinner
        if ((hour == LUNCH_TIME.hour and minute >= 40) or 
            (hour == DINNER_TIME.hour and minute >= 40)):
            label_probabilities['Rice cooker oven'] = round(random.uniform(0.8, 1.0), 6)
        
        # Dishwasher runs every night at 8 PM for 1 hour
        if hour == DISHWASHER_START_HOUR and minute == 0:
            dishwasher_running = True
            dishwasher_end_time = current_time + DISHWASHER_DURATION
            label_probabilities['Dishwasher'] = round(random.uniform(0.8, 1.0), 6)
        elif dishwasher_running:
            if current_time < dishwasher_end_time:
                label_probabilities['Dishwasher'] = round(random.uniform(0.8, 1.0), 6)
            else:
                dishwasher_running = False
        
        # Washer runs twice a week, assign running times (e.g., at 10 AM for 1 hour)
        if is_washer_day and hour == 10 and minute == 0:
            washer_running = True
            washer_end_time = current_time + timedelta(hours=1)
            label_probabilities['Washer'] = round(random.uniform(0.8, 1.0), 6)
        elif washer_running:
            if current_time < washer_end_time:
                label_probabilities['Washer'] = round(random.uniform(0.8, 1.0), 6)
            else:
                washer_running = False
                # Dryer starts immediately after washer ends, runs for 1 hour
                dryer_running = True
                dryer_end_time = current_time + timedelta(hours=1)
                label_probabilities['Dryer'] = round(random.uniform(0.8, 1.0), 6)
        elif dryer_running:
            if current_time < dryer_end_time:
                label_probabilities['Dryer'] = round(random.uniform(0.8, 1.0), 6)
            else:
                dryer_running = False
        
        # Hot water heater always on
        label_probabilities['Hot water heater'] = round(random.uniform(0.8, 1.0), 6)
        
        # Create entry
        entry = {
            "timestamp": current_time.strftime("%Y-%m-%dT%H:%M:%S.%f"),
            "label_probabilities": label_probabilities
        }
        
        # Write the JSON object as a single line
        outfile.write(json.dumps(entry) + '\n')
        
        # Increment current time
        current_time += time_interval
        
        # Optional: Print progress every month
        if current_time.day == 1 and current_time.hour == 0 and current_time.minute == 0:
            print(f"Generated data up to {current_time.strftime('%Y-%m-%d')}")

print(f"Data generation complete. Saved to {output_file_path}")


# Print the first few entries to confirm
for entry in data[:10]:  # First 24 hours (144 intervals of 10 minutes)
    print(json.dumps(entry, indent=4))
# Out:
# Generated data up to 2023-12-01
# Generated data up to 2024-01-01
# Generated data up to 2024-02-01
# Generated data up to 2024-03-01
# Generated data up to 2024-04-01
# Generated data up to 2024-05-01
# Generated data up to 2024-06-01
# Generated data up to 2024-07-01
# Generated data up to 2024-08-01
# Generated data up to 2024-09-01
# Generated data up to 2024-10-01
# Generated data up to 2024-11-01
# Data generation complete. Saved to synthetic_household_data.jsonl
# {
#     "timestamp": "2023-11-21T00:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.970354,
#         "Fridge": 0.839049,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.954577,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.921746
#     }
# }
# {
#     "timestamp": "2023-11-21T00:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.97862,
#         "Fridge": 0.968276,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.879359,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.89068
#     }
# }
# {
#     "timestamp": "2023-11-21T00:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.991583,
#         "Fridge": 0.829178,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.918888,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.824589
#     }
# }
# {
#     "timestamp": "2023-11-21T00:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.972213,
#         "Fridge": 0.915543,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.820611,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.826135
#     }
# }
# {
#     "timestamp": "2023-11-21T00:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.986803,
#         "Fridge": 0.893966,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.90043,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.900491
#     }
# }
# {
#     "timestamp": "2023-11-21T00:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.822766,
#         "Fridge": 0.824491,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.942588,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.944098
#     }
# }
# {
#     "timestamp": "2023-11-21T01:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.957881,
#         "Fridge": 0.953936,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.876998,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.977479
#     }
# }
# {
#     "timestamp": "2023-11-21T01:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.959555,
#         "Fridge": 0.901316,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.871224,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.990912
#     }
# }
# {
#     "timestamp": "2023-11-21T01:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.807795,
#         "Fridge": 0.924986,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.857373,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.949365
#     }
# }
# {
#     "timestamp": "2023-11-21T01:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.870214,
#         "Fridge": 0.955899,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.909443,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.887735
#     }
# }
# {
#     "timestamp": "2023-11-21T01:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.800178,
#         "Fridge": 0.955241,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.84696,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.969967
#     }
# }
# {
#     "timestamp": "2023-11-21T01:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.822935,
#         "Fridge": 0.967701,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.99519,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.863398
#     }
# }
# {
#     "timestamp": "2023-11-21T02:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.830408,
#         "Fridge": 0.944857,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.880765,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.876185
#     }
# }
# {
#     "timestamp": "2023-11-21T02:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.840526,
#         "Fridge": 0.961429,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.85335,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.980896
#     }
# }
# {
#     "timestamp": "2023-11-21T02:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.0,
#         "Fridge": 0.844249,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.874216
#     }
# }
# {
#     "timestamp": "2023-11-21T02:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.967781,
#         "Fridge": 0.941891,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.96064,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.927624
#     }
# }
# {
#     "timestamp": "2023-11-21T02:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.849925,
#         "Fridge": 0.913976,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.934681,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.911559
#     }
# }
# {
#     "timestamp": "2023-11-21T02:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.0,
#         "Fridge": 0.972494,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.820009
#     }
# }
# {
#     "timestamp": "2023-11-21T03:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.996875,
#         "Fridge": 0.930268,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.98055,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.887491
#     }
# }
# {
#     "timestamp": "2023-11-21T03:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.819246,
#         "Fridge": 0.878565,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.946034,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.881533
#     }
# }
# {
#     "timestamp": "2023-11-21T03:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.0,
#         "Fridge": 0.83884,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.966606
#     }
# }
# {
#     "timestamp": "2023-11-21T03:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.920347,
#         "Fridge": 0.886382,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.864227,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.957569
#     }
# }
# {
#     "timestamp": "2023-11-21T03:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.966737,
#         "Fridge": 0.923932,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.889526,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.959997
#     }
# }
# {
#     "timestamp": "2023-11-21T03:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.838108,
#         "Fridge": 0.872943,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.938504,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.959591
#     }
# }
# {
#     "timestamp": "2023-11-21T04:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.944176,
#         "Fridge": 0.867347,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.833607,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.954299
#     }
# }
# {
#     "timestamp": "2023-11-21T04:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.986069,
#         "Fridge": 0.946821,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.869663,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.825094
#     }
# }
# {
#     "timestamp": "2023-11-21T04:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.800279,
#         "Fridge": 0.847736,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.903841,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.800961
#     }
# }
# {
#     "timestamp": "2023-11-21T04:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.0,
#         "Fridge": 0.836432,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.833941
#     }
# }
# {
#     "timestamp": "2023-11-21T04:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.95774,
#         "Fridge": 0.896314,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.908519,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.810321
#     }
# }
# {
#     "timestamp": "2023-11-21T04:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.927488,
#         "Fridge": 0.845541,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.905205,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.86323
#     }
# }
# {
#     "timestamp": "2023-11-21T05:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.0,
#         "Fridge": 0.825345,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.817689
#     }
# }
# {
#     "timestamp": "2023-11-21T05:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.901529,
#         "Fridge": 0.898761,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.834603,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.903283
#     }
# }
# {
#     "timestamp": "2023-11-21T05:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.0,
#         "Fridge": 0.996652,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.926641
#     }
# }
# {
#     "timestamp": "2023-11-21T05:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.0,
#         "Fridge": 0.903187,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.92197
#     }
# }
# {
#     "timestamp": "2023-11-21T05:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.0,
#         "Fridge": 0.996536,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.992894
#     }
# }
# {
#     "timestamp": "2023-11-21T05:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.956898,
#         "Fridge": 0.905175,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.822745,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.855032
#     }
# }
# {
#     "timestamp": "2023-11-21T06:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.947021,
#         "Fridge": 0.994231,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.82841,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.828758,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.967297
#     }
# }
# {
#     "timestamp": "2023-11-21T06:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.968188,
#         "Fridge": 0.893244,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.998013,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.819228,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.916907
#     }
# }
# {
#     "timestamp": "2023-11-21T06:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.859662,
#         "Fridge": 0.830226,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.961325,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.908033,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.893086
#     }
# }
# {
#     "timestamp": "2023-11-21T06:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.998333,
#         "Fridge": 0.963645,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.809699,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.851785,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.979822
#     }
# }
# {
#     "timestamp": "2023-11-21T06:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.936842,
#         "Fridge": 0.870212,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.966462,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.948107
#     }
# }
# {
#     "timestamp": "2023-11-21T06:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.953703,
#         "Fridge": 0.862438,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.898082,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.904825,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.834724
#     }
# }
# {
#     "timestamp": "2023-11-21T07:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.958541,
#         "Fridge": 0.955524,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.915148,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.863258
#     }
# }
# {
#     "timestamp": "2023-11-21T07:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.0,
#         "Fridge": 0.907205,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.958507,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.864503
#     }
# }
# {
#     "timestamp": "2023-11-21T07:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.90762,
#         "Fridge": 0.929255,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.807594,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.957833
#     }
# }
# {
#     "timestamp": "2023-11-21T07:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.954328,
#         "Fridge": 0.942031,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.901694,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.93256,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.840375
#     }
# }
# {
#     "timestamp": "2023-11-21T07:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.914455,
#         "Fridge": 0.896108,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.826298,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.874335,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.807644
#     }
# }
# {
#     "timestamp": "2023-11-21T07:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.938109,
#         "Fridge": 0.987488,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.883543,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.921408
#     }
# }
# {
#     "timestamp": "2023-11-21T08:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.86619,
#         "Laptop charger2": 0.968372,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.85995,
#         "Fridge": 0.913099,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.959408,
#         "Playstation": 0.0,
#         "Fan": 0.910175,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.811514,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.918856
#     }
# }
# {
#     "timestamp": "2023-11-21T08:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.88319,
#         "Laptop charger2": 0.877507,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.899724,
#         "Fridge": 0.942023,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.956568,
#         "Playstation": 0.0,
#         "Fan": 0.814373,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.867099,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.955337
#     }
# }
# {
#     "timestamp": "2023-11-21T08:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.812341,
#         "Laptop charger2": 0.807824,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.951417,
#         "Fridge": 0.969161,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.97557,
#         "Playstation": 0.0,
#         "Fan": 0.996901,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.865696
#     }
# }
# {
#     "timestamp": "2023-11-21T08:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.852642,
#         "Laptop charger2": 0.809191,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.957696,
#         "Fridge": 0.958885,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.91699,
#         "Playstation": 0.0,
#         "Fan": 0.918299,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.930478,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.969458
#     }
# }
# {
#     "timestamp": "2023-11-21T08:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.825043,
#         "Laptop charger2": 0.878711,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.878345,
#         "Fridge": 0.899261,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.966765,
#         "Playstation": 0.0,
#         "Fan": 0.88492,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.86112,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.97841
#     }
# }
# {
#     "timestamp": "2023-11-21T08:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.957266,
#         "Laptop charger2": 0.893194,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.809118,
#         "Fridge": 0.848805,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.949864,
#         "Playstation": 0.0,
#         "Fan": 0.827497,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.814413
#     }
# }
# {
#     "timestamp": "2023-11-21T09:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.800488,
#         "Laptop charger2": 0.945545,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.892592,
#         "Fridge": 0.869748,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.806054,
#         "Playstation": 0.0,
#         "Fan": 0.993879,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.953918
#     }
# }
# {
#     "timestamp": "2023-11-21T09:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.954009,
#         "Laptop charger2": 0.836589,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.976656,
#         "Fridge": 0.941185,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.87998,
#         "Playstation": 0.0,
#         "Fan": 0.833587,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.813743
#     }
# }
# {
#     "timestamp": "2023-11-21T09:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.83487,
#         "Laptop charger2": 0.892878,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.948158,
#         "Fridge": 0.873812,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.85802,
#         "Playstation": 0.0,
#         "Fan": 0.828073,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.931759
#     }
# }
# {
#     "timestamp": "2023-11-21T09:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.840058,
#         "Laptop charger2": 0.861184,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.823667,
#         "Fridge": 0.920816,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.834963,
#         "Playstation": 0.0,
#         "Fan": 0.921098,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.981423
#     }
# }
# {
#     "timestamp": "2023-11-21T09:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.834828,
#         "Laptop charger2": 0.988903,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.992024,
#         "Fridge": 0.922188,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.88245,
#         "Playstation": 0.0,
#         "Fan": 0.833645,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.896181
#     }
# }
# {
#     "timestamp": "2023-11-21T09:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.823961,
#         "Laptop charger2": 0.91515,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.8709,
#         "Fridge": 0.806154,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.905681,
#         "Playstation": 0.0,
#         "Fan": 0.852705,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.964611
#     }
# }
# {
#     "timestamp": "2023-11-21T10:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.854253,
#         "Fridge": 0.882273,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.911171,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.997051
#     }
# }
# {
#     "timestamp": "2023-11-21T10:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.955262,
#         "Fridge": 0.889688,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.808098,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.840062
#     }
# }
# {
#     "timestamp": "2023-11-21T10:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.818385,
#         "Fridge": 0.923251,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.894002,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.819554
#     }
# }
# {
#     "timestamp": "2023-11-21T10:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.886437,
#         "Fridge": 0.821654,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.914039,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.952852
#     }
# }
# {
#     "timestamp": "2023-11-21T10:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.90127,
#         "Fridge": 0.971315,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.920534,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.854693
#     }
# }
# {
#     "timestamp": "2023-11-21T10:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.941748,
#         "Fridge": 0.969162,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.827097,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.927173
#     }
# }
# {
#     "timestamp": "2023-11-21T11:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.968677,
#         "Fridge": 0.849776,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.923341,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.847802
#     }
# }
# {
#     "timestamp": "2023-11-21T11:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.921913,
#         "Fridge": 0.864545,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.85259,
#         "Aspiradora": 0.0,
# ...
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.936137,
#         "Alexa": 0.831226,
#         "Speaker": 0.873875,
#         "TV1": 0.95053,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.836785,
#         "Laptop charger2": 0.991801,
#         "TV2": 0.951131,
#         "TV3": 0.959117,
#         "HVAC": 0.0,
#         "Fridge": 0.941154,
#         "Dishwasher": 0.996534,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.887207,
#         "Playstation": 0.90722,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.998132
#     }
# }
# {
#     "timestamp": "2023-11-21T20:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.891865,
#         "Alexa": 0.981605,
#         "Speaker": 0.955089,
#         "TV1": 0.962733,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.924089,
#         "Laptop charger2": 0.996802,
#         "TV2": 0.946632,
#         "TV3": 0.875127,
#         "HVAC": 0.884885,
#         "Fridge": 0.850852,
#         "Dishwasher": 0.855857,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.982461,
#         "Playstation": 0.87421,
#         "Fan": 0.986472,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.864652
#     }
# }
# {
#     "timestamp": "2023-11-21T20:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.892166,
#         "Alexa": 0.96437,
#         "Speaker": 0.877045,
#         "TV1": 0.943813,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.997514,
#         "Laptop charger2": 0.96207,
#         "TV2": 0.907934,
#         "TV3": 0.867308,
#         "HVAC": 0.907859,
#         "Fridge": 0.922401,
#         "Dishwasher": 0.852353,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.834347,
#         "Playstation": 0.823759,
#         "Fan": 0.890745,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.815695
#     }
# }
# {
#     "timestamp": "2023-11-21T20:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.887189,
#         "Alexa": 0.929575,
#         "Speaker": 0.895535,
#         "TV1": 0.813252,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.884497,
#         "Laptop charger2": 0.811201,
#         "TV2": 0.916519,
#         "TV3": 0.898165,
#         "HVAC": 0.860627,
#         "Fridge": 0.963572,
#         "Dishwasher": 0.948903,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.887027,
#         "Playstation": 0.87346,
#         "Fan": 0.875744,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.837388
#     }
# }
# {
#     "timestamp": "2023-11-21T21:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.904485,
#         "Alexa": 0.807075,
#         "Speaker": 0.957917,
#         "TV1": 0.965865,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.865009,
#         "Laptop charger2": 0.921817,
#         "TV2": 0.839972,
#         "TV3": 0.90191,
#         "HVAC": 0.955018,
#         "Fridge": 0.840623,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.896041,
#         "Playstation": 0.934297,
#         "Fan": 0.955922,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.961217
#     }
# }
# {
#     "timestamp": "2023-11-21T21:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.914141,
#         "Alexa": 0.978093,
#         "Speaker": 0.915138,
#         "TV1": 0.813844,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.944568,
#         "Laptop charger2": 0.867421,
#         "TV2": 0.911812,
#         "TV3": 0.988844,
#         "HVAC": 0.974926,
#         "Fridge": 0.81248,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.846844,
#         "Playstation": 0.997315,
#         "Fan": 0.83521,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.897066
#     }
# }
# {
#     "timestamp": "2023-11-21T21:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.880041,
#         "Alexa": 0.908643,
#         "Speaker": 0.959561,
#         "TV1": 0.841907,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.839873,
#         "Laptop charger2": 0.992556,
#         "TV2": 0.806897,
#         "TV3": 0.827351,
#         "HVAC": 0.0,
#         "Fridge": 0.980626,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.946057,
#         "Playstation": 0.945746,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.935808
#     }
# }
# {
#     "timestamp": "2023-11-21T21:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.944449,
#         "Alexa": 0.971214,
#         "Speaker": 0.97095,
#         "TV1": 0.968114,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.841152,
#         "Laptop charger2": 0.852763,
#         "TV2": 0.893293,
#         "TV3": 0.968671,
#         "HVAC": 0.0,
#         "Fridge": 0.859547,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.992555,
#         "Playstation": 0.865426,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.807988
#     }
# }
# {
#     "timestamp": "2023-11-21T21:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.901172,
#         "Alexa": 0.947781,
#         "Speaker": 0.946391,
#         "TV1": 0.984625,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.915952,
#         "Laptop charger2": 0.943398,
#         "TV2": 0.918294,
#         "TV3": 0.897314,
#         "HVAC": 0.887946,
#         "Fridge": 0.996718,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.901441,
#         "Playstation": 0.807358,
#         "Fan": 0.804785,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.914942
#     }
# }
# {
#     "timestamp": "2023-11-21T21:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.815014,
#         "Alexa": 0.822346,
#         "Speaker": 0.912877,
#         "TV1": 0.957871,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.949428,
#         "Laptop charger2": 0.828878,
#         "TV2": 0.888929,
#         "TV3": 0.969012,
#         "HVAC": 0.0,
#         "Fridge": 0.88735,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.861223,
#         "Playstation": 0.961251,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.845063
#     }
# }
# {
#     "timestamp": "2023-11-21T22:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.924981,
#         "Alexa": 0.836226,
#         "Speaker": 0.898123,
#         "TV1": 0.947267,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.881206,
#         "TV3": 0.858715,
#         "HVAC": 0.953271,
#         "Fridge": 0.869186,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.97695,
#         "Fan": 0.833953,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.943096
#     }
# }
# {
#     "timestamp": "2023-11-21T22:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.920391,
#         "Alexa": 0.805887,
#         "Speaker": 0.811152,
#         "TV1": 0.997951,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.931171,
#         "TV3": 0.953482,
#         "HVAC": 0.0,
#         "Fridge": 0.816436,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.83532,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.86407
#     }
# }
# {
#     "timestamp": "2023-11-21T22:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.974779,
#         "Alexa": 0.940702,
#         "Speaker": 0.932897,
#         "TV1": 0.814324,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.933426,
#         "TV3": 0.843703,
#         "HVAC": 0.916994,
#         "Fridge": 0.800964,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.853891,
#         "Fan": 0.941718,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.809104
#     }
# }
# {
#     "timestamp": "2023-11-21T22:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.838448,
#         "Alexa": 0.98524,
#         "Speaker": 0.804414,
#         "TV1": 0.924213,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.909865,
#         "TV3": 0.838991,
#         "HVAC": 0.857622,
#         "Fridge": 0.856053,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.969191,
#         "Fan": 0.935774,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.893551
#     }
# }
# {
#     "timestamp": "2023-11-21T22:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.894011,
#         "Alexa": 0.984702,
#         "Speaker": 0.82687,
#         "TV1": 0.806871,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.845524,
#         "TV3": 0.88396,
#         "HVAC": 0.0,
#         "Fridge": 0.840633,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.856635,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.913494
#     }
# }
# {
#     "timestamp": "2023-11-21T22:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.973988,
#         "Alexa": 0.817829,
#         "Speaker": 0.832011,
#         "TV1": 0.957103,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.987325,
#         "TV3": 0.895179,
#         "HVAC": 0.980195,
#         "Fridge": 0.87584,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.904324,
#         "Fan": 0.980537,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.830119
#     }
# }
# {
#     "timestamp": "2023-11-21T23:00:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.961058,
#         "Fridge": 0.872824,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.806515,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.947774
#     }
# }
# {
#     "timestamp": "2023-11-21T23:10:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.843601,
#         "Fridge": 0.927998,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.841465,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.889287
#     }
# }
# {
#     "timestamp": "2023-11-21T23:20:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.998393,
#         "Fridge": 0.989559,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.855282,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.828907
#     }
# }
# {
#     "timestamp": "2023-11-21T23:30:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.948535,
#         "Fridge": 0.809168,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.952055,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.97632
#     }
# }
# {
#     "timestamp": "2023-11-21T23:40:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.811427,
#         "Fridge": 0.95711,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.850879,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.957434
#     }
# }
# {
#     "timestamp": "2023-11-21T23:50:00.000000",
#     "label_probabilities": {
#         "Ipad": 0.0,
#         "Mac": 0.0,
#         "Floor_lamp": 0.0,
#         "Alexa": 0.0,
#         "Speaker": 0.0,
#         "TV1": 0.0,
#         "Microwave": 0.0,
#         "Laptop charger1": 0.0,
#         "Laptop charger2": 0.0,
#         "TV2": 0.0,
#         "TV3": 0.0,
#         "HVAC": 0.0,
#         "Fridge": 0.983416,
#         "Dishwasher": 0.0,
#         "Dryer": 0.0,
#         "Washer": 0.0,
#         "Monitor": 0.0,
#         "Playstation": 0.0,
#         "Fan": 0.0,
#         "Aspiradora": 0.0,
#         "Air fryer": 0.0,
#         "Kettle": 0.0,
#         "Rice cooker oven": 0.0,
#         "Hot water heater": 0.904935
#     }
# }

# %% [markdown]
# # upload data to dynamo

# %%
import boto3
import json
import logging
import sys
from decimal import Decimal  # Import Decimal for DynamoDB compatibility

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')


def load_config(config_path='config.json'):
    """
    Load AWS and DynamoDB configuration from a JSON file.
    """
    try:
        with open(config_path, 'r') as file:
            config = json.load(file)
        
        aws_config = config.get('aws', {})
        dynamodb_config = config.get('dynamodb', {})
        
        access_key = aws_config.get('access_key_id')
        secret_key = aws_config.get('secret_access_key')
        region = aws_config.get('region_name')
        table_name = dynamodb_config.get('table_name')
        file_name = dynamodb_config.get('file_name')
        
        if not all([access_key, secret_key, region, table_name, file_name]):
            raise ValueError("Missing AWS or DynamoDB configuration in config.json.")
        
        return {
            'access_key': access_key,
            'secret_key': secret_key,
            'region': region,
            'table_name': table_name,
            'file_name': file_name
        }
    except FileNotFoundError:
        logging.error(f"Configuration file {config_path} not found.")
        sys.exit(1)
    except json.JSONDecodeError as e:
        logging.error(f"Error parsing {config_path}: {e}")
        sys.exit(1)
    except ValueError as ve:
        logging.error(f"Configuration error: {ve}")
        sys.exit(1)


def convert_float_to_decimal(item):
    """
    Recursively convert all float values in a dictionary to Decimal.
    """
    if isinstance(item, list):
        return [convert_float_to_decimal(sub_item) for sub_item in item]
    elif isinstance(item, dict):
        return {k: convert_float_to_decimal(v) for k, v in item.items()}
    elif isinstance(item, float):  # Convert float to Decimal
        return Decimal(str(item))
    return item


def upload_to_dynamodb(config):
    """
    Upload data from a JSON Lines file to DynamoDB using batch_writer().
    """
    dynamodb = boto3.resource(
        'dynamodb',
        region_name=config['region'],
        aws_access_key_id=config['access_key'],
        aws_secret_access_key=config['secret_key']
    )
    table = dynamodb.Table(config['table_name'])
    file_name = config['file_name']
    
    try:
        with open(file_name, 'r') as file:
            with table.batch_writer() as batch:
                for line_number, line in enumerate(file, start=1):
                    try:
                        # Parse the line as JSON
                        item = json.loads(line, parse_float=Decimal)  # Convert floats to Decimal
                        
                        # Validate 'timestamp'
                        if 'timestamp' not in item:
                            logging.warning(f"Line {line_number}: 'timestamp' field missing. Skipping item.")
                            continue
                        if not isinstance(item['timestamp'], str):
                            logging.warning(f"Line {line_number}: 'timestamp' is not a string. Skipping item.")
                            continue
                        
                        # Convert any remaining float types in 'label_probabilities' to Decimal
                        if 'label_probabilities' in item:
                            item['label_probabilities'] = convert_float_to_decimal(item['label_probabilities'])
                        
                        # Add the item to the batch
                        batch.put_item(Item=item)
                        
                        if line_number % 10000 == 0:
                            logging.info(f"Processed {line_number} items...")
                    
                    except json.JSONDecodeError as e:
                        logging.error(f"JSON decode error on line {line_number}: {e}")
                    except Exception as e:
                        logging.error(f"Unexpected error on line {line_number}: {e}")
        
        logging.info("Data upload complete.")
    
    except FileNotFoundError:
        logging.error(f"JSON file {file_name} not found.")
        sys.exit(1)
    except Exception as e:
        logging.error(f"An error occurred during upload: {e}")
        sys.exit(1)


if __name__ == "__main__":
    config = load_config('config.json')
    upload_to_dynamodb(config)
# Out:
# 2024-11-22 19:32:05,297 - INFO - Processed 10000 items...
# 2024-11-22 19:32:26,397 - INFO - Processed 20000 items...
# 2024-11-22 19:32:50,262 - INFO - Processed 30000 items...
# 2024-11-22 19:33:10,650 - INFO - Processed 40000 items...
# 2024-11-22 19:33:30,077 - INFO - Processed 50000 items...
# 2024-11-22 19:33:35,293 - INFO - Data upload complete.
